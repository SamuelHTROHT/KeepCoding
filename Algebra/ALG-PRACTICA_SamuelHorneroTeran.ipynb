# %% [markdown]
# # Módulo de Matemáticas 101: práctica
#
# Vamos a poner de nuevo en práctica lo que hemos visto en este módulo. La práctica se centra en la regresión lineal (¡tema muy importante!) y podéis preguntarme las dudas que tengáis por Discord. ¡Mucha suerte!

# %% [markdown]
# ## 1. Regresión lineal con mínimos cuadrados
#
# En este ejercicio vamos a implementar la forma matricial de la regresión lineal con el método de los mínimos cuadrados. Para ello, tendrás que:
#
# - Explorar un dataset
# - Implementar la regresión lineal
# - Aplicarla a un dataset concreto
#
# Como recordatorio, los valores de los pesos $\widehat{w}$ vienen dados por:
#
# <center>$\widehat{w} = (X^T X)^{-1}X^T y,$</center>
#
# Donde $y$ es la variable a predecir y $X$ la matriz de features (NOTA: revisa cómo se define en los apuntes). Sabemos que los pesos van a ser los parámetros de la ecuación lineal que estamos intentando ajustar y tendremos uno por cada variable de entrada que usemos y además un término independiente o bias.

# %% [markdown]
# ### 1.1 Carga del dataset y exploración de datos
#
# Vamos a usar el dataset de [Auto MPG](https://archive.ics.uci.edu/dataset/9/auto+mpg) que podemos encontrar en el [repositorio de Machine learning de UC Irvine](https://archive.ics.uci.edu/). Lo primero, vamos a familiarizarnos con los datos.
#
# En el propio repositorio nos indican cómo descargar el dataset con su librería (podemos consultar el código fuente si queremos).

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ucimlrepo) (3.0.0)
# Requirement already satisfied: certifi>=2020.12.5 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ucimlrepo) (2026.1.4)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
auto_mpg = fetch_ucirepo(id=9) 
  
# data (as pandas dataframes) 
X = auto_mpg.data.features 
y = auto_mpg.data.targets 
  
# metadata 
print(auto_mpg.metadata) 
  
# variable information 
print(auto_mpg.variables)
# Out:
# {'uci_id': 9, 'name': 'Auto MPG', 'repository_url': 'https://archive.ics.uci.edu/dataset/9/auto+mpg', 'data_url': 'https://archive.ics.uci.edu/static/public/9/data.csv', 'abstract': 'Revised from CMU StatLib library, data concerns city-cycle fuel consumption', 'area': 'Other', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 398, 'num_features': 7, 'feature_types': ['Real', 'Categorical', 'Integer'], 'demographics': [], 'target_col': ['mpg'], 'index_col': ['car_name'], 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1993, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5859H', 'creators': ['R. Quinlan'], 'intro_paper': None, 'additional_info': {'summary': 'This dataset is a slightly modified version of the dataset provided in the StatLib library.  In line with the use by Ross Quinlan (1993) in predicting the attribute "mpg", 8 of the original instances were removed because they had unknown values for the "mpg" attribute.  The original dataset is available in the file "auto-mpg.data-original".\r\n\r\n"The data concerns city-cycle fuel consumption in miles per gallon, to be predicted in terms of 3 multivalued discrete and 5 continuous attributes." (Quinlan, 1993)', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '    1. mpg:           continuous\r\n    2. cylinders:     multi-valued discrete\r\n    3. displacement:  continuous\r\n    4. horsepower:    continuous\r\n    5. weight:        continuous\r\n    6. acceleration:  continuous\r\n    7. model year:    multi-valued discrete\r\n    8. origin:        multi-valued discrete\r\n    9. car name:      string (unique for each instance)', 'citation': None}}
#            name     role         type demographic description units  \
# 0  displacement  Feature   Continuous        None        None  None
# 1           mpg   Target   Continuous        None        None  None
# 2     cylinders  Feature      Integer        None        None  None
# 3    horsepower  Feature   Continuous        None        None  None
# 4        weight  Feature   Continuous        None        None  None
# 5  acceleration  Feature   Continuous        None        None  None
# 6    model_year  Feature      Integer        None        None  None
# 7        origin  Feature      Integer        None        None  None
# 8      car_name       ID  Categorical        None        None  None
#
#   missing_values
# 0             no
# 1             no
# 2             no
# 3            yes
# 4             no
# 5             no
# 6             no
# 7             no
# 8             no

# %% [markdown]
# Con la función `head` de Pandas podemos ver las primeras filas del dataset.

# %%
X.head()
# Out:
#    displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 0         307.0          8       130.0    3504          12.0          70
# 1         350.0          8       165.0    3693          11.5          70
# 2         318.0          8       150.0    3436          11.0          70
# 3         304.0          8       150.0    3433          12.0          70
# 4         302.0          8       140.0    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y.head()
# Out:
#     mpg
# 0  18.0
# 1  15.0
# 2  18.0
# 3  16.0
# 4  17.0

# %% [markdown]
# En este punto, puedes hacer cualquier otro análisis exploratorio que creas conveniente.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ----------------------------------- ---- 7.3/8.3 MB 36.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 36.6 MB/s  0:00:00
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 76.8 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.1.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 97.4 MB/s  0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.4.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.0-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------------- - 7.9/8.1 MB 41.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 39.6 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.0-cp314-cp314-win_amd64.whl (37.1 MB)
#    ---------------------------------------- 0.0/37.1 MB ? eta -:--:--
#    ------------------------ --------------- 22.8/37.1 MB 110.7 MB/s eta 0:00:01
#    ---------------------------------------- 37.1/37.1 MB 98.0 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# A continuación, crea una función a la que le pases los dataframes de features y de target y el nombre de la variable y haga la gráfica del target (consumo en millas por galón) vs la variable que le ha llegado por parámetro. Puedes ver un ejemplo de gráfica más abajo, pero usa los parámetros que quieras en cuanto a color de los puntos, grids etc.

# %%
import matplotlib.pyplot as plt

def visualiza(df, y, nombre_columna):
    plt.figure()
    plt.scatter(df[nombre_columna], y)
    plt.xlabel(nombre_columna)
    plt.ylabel("Consumo (millas por galón)")
    plt.title(f"Consumo vs {nombre_columna}")
    plt.grid(True)
    plt.show()
    

visualiza(X, y, 'horsepower')

# %%
visualiza(X, y, 'acceleration')

# %%
visualiza(X, y, 'weight')

# %% [markdown]
# IMPORTANTE: Aunque lo ideal sería un modelo multivariante, vamos a elegir la variable `weight` y hacer una regresión lineal solo con esta variable.

# %% [markdown]
# ### 1.2 Implementación del modelo
#
# En este punto vamos a dar un paso atrás y olvidarnos de los datos de consumo por un momento, porque el algoritmo que vamos a implementar serviría para cualquier conjunto de datos.
#
# Lo primero, implementa una función que devuelva los valores de $\widehat{w}$ dados X e y. Si se da el caso de que el dataset tiene más features que observaciones, lo mostramos por pantalla y salimos de la función. Lo hacemos porque, como vimos en clase, los resultados no van a ser buenos si el número de observaciones es menor.

# %%
import numpy as np

def pesos_ols(X, y):
    X_arr = np.array(X, dtype=float)
    y_arr = np.array(y, dtype=float)
    N, d = X_arr.shape
    if d > N:
        print(f"Error: El dataset tiene más features ({d}) que observaciones ({N}).")
        print("Los resultados no serían fiables.")
        return None
    X_b = np.c_[np.ones((N, 1)), X_arr]
    try:
        X_T = X_b.T
        inverse_XTX = np.linalg.inv(X_T @ X_b)
        w_hat = inverse_XTX @ X_T @ y_arr
        return w_hat
    except np.linalg.LinAlgError:
        print("Error: La matriz (X^T X) no es invertible (es singular).")
        return None

# %%
# Arrays de prueba!! No son dataset reales y no hace falta que los dibujemos
X_prueba = np.array([[1710, 1262, 1786, 1717, 2198, 1362, 1694, 2090, 1774, 1077], 
              [2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939]])
y_prueba = np.array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000, 129900, 118000])
pesos_ols(X_prueba, y_prueba)
# Out:
# Error: El dataset tiene más features (10) que observaciones (2).
# Los resultados no serían fiables.

# %%
X_prueba = np.array([[1710, 1262, 1786, 1717, 2198, 1362, 1694, 2090, 1774, 1077], 
              [2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939]]).reshape(10,2)
y_prueba = np.array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 200000, 129900, 118000])
pesos_ols(X_prueba, y_prueba)
# Out:
# array([ 1.98968523e+05,  7.36278026e+01, -8.63759760e+01])

# %% [markdown]
# Hasta aquí hemos implementado el algoritmo de mínimos cuadrados y lo hemos probado en un array de tamaño 2x10, pero aún no lo hemos probado con ningún dataset real.

# %% [markdown]
# ### 1.3 Prueba del modelo en los datos de consumo de coches
#
# Ahora sí, ya podemos usar nuestra función `pesos` en el dataset real que hemos descargado, el de consumo de combustible. Para ver el ajuste, dibuja de nuevo los datos junto con la recta que has obtenido, en la misma gráfica. Tendrás que convertir los dataframes de Pandas en arrays de numpy para poder aplicar las operaciones matriciales.
#
# TIP: Revisa las dimensiones de todos los arrays para ver que son correctas.

# %%
import pandas as pd
X_weight = X[['weight']].values
y_vals = y.values
mask = ~np.isnan(X_weight).any(axis=1) & ~np.isnan(y_vals).any(axis=1)
X_clean = X_weight[mask]
y_clean = y_vals[mask]
w_hat = pesos_ols(X_clean, y_clean)
X_range = np.linspace(X_clean.min(), X_clean.max(), 100).reshape(-1, 1)
X_range_b = np.c_[np.ones((100, 1)), X_range]
y_range_pred = X_range_b @ w_hat

plt.figure(figsize=(10, 6))
plt.scatter(X_clean, y_clean, color='blue', alpha=0.5, label='Datos reales')
plt.plot(X_range, y_range_pred, color='red', linewidth=3, label='Recta de regresión (Manual)')
intercepto = w_hat[0][0]
pendiente = w_hat[1][0]

plt.title(f'Regresión Lineal Manual: MPG vs Peso\n(w0: {intercepto:.2f}, w1: {pendiente:.4f})', fontsize=14)
plt.xlabel('Peso del coche (Weight)', fontsize=12)
plt.ylabel('Millas por galón (MPG)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Por último, vamos a comprar el resultado con el que nos da `scikit-learn`para ver si nuestra implementación tiene buena pinta. Podemos ver cómo funciona en la [documentación](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html).

# %%
from sklearn.linear_model import LinearRegression
X_plot = X[['weight']].values
y_plot = y.values
X_range = np.linspace(X_plot.min(), X_plot.max(), 100).reshape(-1, 1)
y_range_pred = lr.predict(X_range)
plt.figure(figsize=(10, 6))
plt.scatter(X_plot, y_plot, color='blue', alpha=0.5, label='Datos reales')
plt.plot(X_range, y_range_pred, color='red', linewidth=3, label='Recta de regresión')
plt.title(f'Regresión Lineal Simple: MPG vs Peso\n(Pendiente: {lr.coef_[0][0]:.4f})', fontsize=14)
plt.xlabel('Peso del coche (Weight)', fontsize=12)
plt.ylabel('Millas por galón (MPG)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
# Out:
# c:\Users\samue\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **TODO**: Analiza el resultado obtenido y compáralo con el de sklearn (solo hay que ver si coincide o no para saber si te has equivocado en algún punto). Si coincide, ¡enhorabuena! Ya sabes implementar tu primer modelo de Machine Learning desde la base.

# %%
# Out:
# Pesos manuales (intercepto, pendiente): [130. 165. 150. 150. 140. 198. 220. 215. 225. 190. 170. 160. 150. 225.
#   95.  95.  97.  85.  88.  46.  87.  90.  95. 113.  90. 215. 200. 210.
#  193.  88.  90.  95.  nan 100. 105. 100.  88. 100. 165. 175. 153. 150.
#  180. 170. 175. 110.  72. 100.  88.  86.  90.  70.  76.  65.  69.  60.
#   70.  95.  80.  54.  90.  86. 165. 175. 150. 153. 150. 208. 155. 160.
#  190.  97. 150. 130. 140. 150. 112.  76.  87.  69.  86.  92.  97.  80.
#   88. 175. 150. 145. 137. 150. 198. 150. 158. 150. 215. 225. 175. 105.
#  100. 100.  88.  95.  46. 150. 167. 170. 180. 100.  88.  72.  94.  90.
#   85. 107.  90. 145. 230.  49.  75.  91. 112. 150. 110. 122. 180.  95.
#   nan 100. 100.  67.  80.  65.  75. 100. 110. 105. 140. 150. 150. 140.
#  150.  83.  67.  78.  52.  61.  75.  75.  75.  97.  93.  67.  95. 105.
#   72.  72. 170. 145. 150. 148. 110. 105. 110.  95. 110. 110. 129.  75.
#   83. 100.  78.  96.  71.  97.  97.  70.  90.  95.  88.  98. 115.  53.
#   86.  81.  92.  79.  83. 140. 150. 120. 152. 100. 105.  81.  90.  52.
#   60.  70.  53. 100.  78. 110.  95.  71.  70.  75.  72. 102. 150.  88.
#  108. 120. 180. 145. 130. 150.  68.  80.  58.  96.  70. 145. 110. 145.
#  130. 110. 105. 100.  98. 180. 170. 190. 149.  78.  88.  75.  89.  63.
#   83.  67.  78.  97. 110. 110.  48.  66.  52.  70.  60. 110. 140. 139.
#  105.  95.  85.  88. 100.  90. 105.  85. 110. 120. 145. 165. 139. 140.
#   68.  95.  97.  75.  95. 105.  85.  97. 103. 125. 115. 133.  71.  68.
#  115.  85.  88.  90. 110. 130. 129. 138. 135. 155. 142. 125. 150.  71.
#   65.  80.  80.  77. 125.  71.  90.  70.  70.  65.  69.  90. 115. 115.
#   90.  76.  60.  70.  65.  90.  88.  90.  90.  78.  90.  75.  92.  75.
#   65. 105.  65.  48.  48.  67.  67.  67.  nan  67.  62. 132. 100.  88.
#   nan  72.  84.  84.  92. 110.  84.  58.  64.  60.  67.  65.  62.  68.
#   63.  65.  65.  74.  nan  75.  75. 100.  74.  80.  76. 116. 120. 110.
#  105.  88.  85.  88.  88.  88.  85.  84.  90.  92.  nan  74.  68.  68.
#   63.  70.  88.  75.  70.  67.  67.  67. 110.  85.  92. 112.  96.  84.
#   90.  86.  52.  84.  79.  82.]

# %% [markdown]
# ### 1.4 Compara el método de mínimos cuadrados y el descenso del gradiente para obtener los coeficientes de una regresión lineal

# %% [markdown]
# Minimos cuadrados se utiliza cuando puedes almacenar todos los datos ya que apareces en el punto mas bajo es exacto e instantaneo, mientras que descenso de gradiente tienes que ir dando pasos ya que solo puedes sentir la pendiente es bueno para trabajar con volumenes de datos mayores.

# %% [markdown]
# ## 2. Optimización con descenso del gradiente
#
# Vamos a resolver el mismo problema usando el descenso del gradiente en lugar de la solución analítica. El descenso del gradiente es un método de optimización iterativo que usa el operador gradiente.
#
# Como es iterativo, necesitamos decirle cuándo tiene que parar y darnos la solución. En este caso, le vamos a decir que pare y nos devuelva la solución después de un número de iteraciones que le pasaremos como parámetro. La ecuación iterativa es.
#
# $$w^{t+1} = w^t - \eta \cdot \nabla f(w)$$
#
# donde f es nuestra función objetivo, y w es un vector. Para la función objetivo, vamos a usar el error RSS, que querremos minimizar.
#
# $$ RSS(w) = \frac{1}{2}\sum_{n=1}^{N}[y_n-f(x_n)]^2$$
#
# y cuyo gradiente es:
#
# $$\nabla RSS(w) = X^T(Xw^t-y)$$
#
# TIP: Ten en cuenta que el RSS también lo puedes escribir como $\frac{1}{2}\sum_{n=1}^{N}[y_n-\hat{y_n}]^2$ donde $\hat{y_n} = X \hat{w}$ en cada paso.

# %% [markdown]
# ### 2.1 Implementar el descenso del gradiente
#
# Completa las siguientes funciones para implementar el descenso del gradiente con la función objetivo de la regresión lineal. La función necesitará:
#
# - La entrada X y salida y de la regresión
# - Un punto inicial desde el que empezar a iterar
# - El número de iteraciones
# - El learning rate
#
# La función nos devolverá un array con las w resultantes de las iteraciones y otro con el valor de la función en cada paso del algoritmo, a la que también se conoce como *loss function*.

# %%
import numpy as np
def gradient_descent(X, y, w0, n_iter, eta, tol=0.1): 
    loss_iter = []
    w_iter = [w0.copy()]
    w = w0.copy()
    
    N = len(y)
    X_b = np.c_[np.ones((N, 1)), X]
    for i in range(n_iter):
        y_hat = X_b @ w
        error = y_hat - y
        loss = (1/N) * np.sum(error**2)
        loss_iter.append(loss)
        if i > 0:
            diferencia_error = abs(loss_iter[-2] - loss_iter[-1])
            print(f"Iteración {i}: Mejora de {diferencia_error:.6f}")
            if diferencia_error < tol:
                print(f"Detenido por convergencia en la iteración {i}")
                break
        gradient = (2/N) * (X_b.T @ error)
        w = w - eta * gradient
        w_iter.append(w.copy())
        
    return np.array(w_iter), np.array(loss_iter)

X_real = X_clean.copy()
y_real = y_clean.copy()

# Como el peso es muy grande, dividimos entre 10000 para no usar un eta muy bajo
X_scaled = X_real / 10000 

eta = 0.1 
iteraciones = 10000
tol = 0.0001

np.random.seed(42)
w0_real = np.random.randn(2, 1)
weights_history, loss_history = gradient_descent(X_scaled, y_real, w0_real, iteraciones, eta, tol=tol)
w_final = weights_history[-1]
intercepto_gd = w_final[0][0]

pendiente_gd = w_final[1][0] / 1000 

print(f"--- Resultados Finales ---")
print(f"Intercepto (w0): {intercepto_gd:.4f}  (Debería ser ~46.2)")
print(f"Pendiente (w1): {pendiente_gd:.6f} (Debería ser ~-0.0076")

plt.figure(figsize=(10, 4))
plt.plot(loss_history)
plt.title('Curva de Aprendizaje (Reducción del Error)')
plt.xlabel('Iteración')
plt.ylabel('Costo (MSE)')
plt.grid(True)
plt.show()
# Out:
# Iteración 1: Mejora de 203.695461
# Iteración 2: Mejora de 124.689817
# Iteración 3: Mejora de 76.346617
# Iteración 4: Mejora de 46.765579
# Iteración 5: Mejora de 28.664993
# Iteración 6: Mejora de 17.589226
# Iteración 7: Mejora de 10.811903
# Iteración 8: Mejora de 6.664771
# Iteración 9: Mejora de 4.127038
# Iteración 10: Mejora de 2.574086
# Iteración 11: Mejora de 1.623716
# Iteración 12: Mejora de 1.042063
# Iteración 13: Mejora de 0.686026
# Iteración 14: Mejora de 0.468041
# Iteración 15: Mejora de 0.334531
# Iteración 16: Mejora de 0.252711
# Iteración 17: Mejora de 0.202520
# Iteración 18: Mejora de 0.171682
# Iteración 19: Mejora de 0.152687
# Iteración 20: Mejora de 0.140939
# Iteración 21: Mejora de 0.133626
# Iteración 22: Mejora de 0.129027
# Iteración 23: Mejora de 0.126088
# Iteración 24: Mejora de 0.124166
# Iteración 25: Mejora de 0.122867
# Iteración 26: Mejora de 0.121949
# Iteración 27: Mejora de 0.121264
# Iteración 28: Mejora de 0.120723
# Iteración 29: Mejora de 0.120269
# Iteración 30: Mejora de 0.119870
# Iteración 31: Mejora de 0.119504
# Iteración 32: Mejora de 0.119159
# Iteración 33: Mejora de 0.118827
# Iteración 34: Mejora de 0.118503
# Iteración 35: Mejora de 0.118185
# Iteración 36: Mejora de 0.117870
# Iteración 37: Mejora de 0.117558
# Iteración 38: Mejora de 0.117247
# Iteración 39: Mejora de 0.116938
# Iteración 40: Mejora de 0.116630
# Iteración 41: Mejora de 0.116324
# Iteración 42: Mejora de 0.116018
# Iteración 43: Mejora de 0.115713
# Iteración 44: Mejora de 0.115409
# Iteración 45: Mejora de 0.115106
# Iteración 46: Mejora de 0.114804
# Iteración 47: Mejora de 0.114502
# Iteración 48: Mejora de 0.114202
# Iteración 49: Mejora de 0.113902
# Iteración 50: Mejora de 0.113603
# Iteración 51: Mejora de 0.113304
# Iteración 52: Mejora de 0.113007
# Iteración 53: Mejora de 0.112710
# Iteración 54: Mejora de 0.112414
# Iteración 55: Mejora de 0.112119
# Iteración 56: Mejora de 0.111824
# Iteración 57: Mejora de 0.111530
# Iteración 58: Mejora de 0.111238
# Iteración 59: Mejora de 0.110945
# Iteración 60: Mejora de 0.110654
# Iteración 61: Mejora de 0.110363
# Iteración 62: Mejora de 0.110074
# Iteración 63: Mejora de 0.109785
# Iteración 64: Mejora de 0.109496
# Iteración 65: Mejora de 0.109209
# Iteración 66: Mejora de 0.108922
# Iteración 67: Mejora de 0.108636
# Iteración 68: Mejora de 0.108351
# Iteración 69: Mejora de 0.108066
# Iteración 70: Mejora de 0.107782
# Iteración 71: Mejora de 0.107499
# Iteración 72: Mejora de 0.107217
# Iteración 73: Mejora de 0.106935
# Iteración 74: Mejora de 0.106654
# Iteración 75: Mejora de 0.106374
# Iteración 76: Mejora de 0.106095
# Iteración 77: Mejora de 0.105816
# Iteración 78: Mejora de 0.105538
# Iteración 79: Mejora de 0.105261
# Iteración 80: Mejora de 0.104985
# Iteración 81: Mejora de 0.104709
# Iteración 82: Mejora de 0.104434
# Iteración 83: Mejora de 0.104160
# Iteración 84: Mejora de 0.103886
# Iteración 85: Mejora de 0.103613
# Iteración 86: Mejora de 0.103341
# Iteración 87: Mejora de 0.103070
# Iteración 88: Mejora de 0.102799
# Iteración 89: Mejora de 0.102529
# Iteración 90: Mejora de 0.102260
# Iteración 91: Mejora de 0.101991
# Iteración 92: Mejora de 0.101724
# Iteración 93: Mejora de 0.101456
# Iteración 94: Mejora de 0.101190
# Iteración 95: Mejora de 0.100924
# Iteración 96: Mejora de 0.100659
# Iteración 97: Mejora de 0.100395
# Iteración 98: Mejora de 0.100131
# Iteración 99: Mejora de 0.099868
# Iteración 100: Mejora de 0.099606
# Iteración 101: Mejora de 0.099344
# Iteración 102: Mejora de 0.099083
# Iteración 103: Mejora de 0.098823
# Iteración 104: Mejora de 0.098564
# Iteración 105: Mejora de 0.098305
# Iteración 106: Mejora de 0.098047
# Iteración 107: Mejora de 0.097789
# Iteración 108: Mejora de 0.097532
# Iteración 109: Mejora de 0.097276
# Iteración 110: Mejora de 0.097021
# Iteración 111: Mejora de 0.096766
# Iteración 112: Mejora de 0.096512
# Iteración 113: Mejora de 0.096258
# Iteración 114: Mejora de 0.096006
# Iteración 115: Mejora de 0.095753
# Iteración 116: Mejora de 0.095502
# Iteración 117: Mejora de 0.095251
# Iteración 118: Mejora de 0.095001
# Iteración 119: Mejora de 0.094752
# Iteración 120: Mejora de 0.094503
# Iteración 121: Mejora de 0.094255
# Iteración 122: Mejora de 0.094007
# Iteración 123: Mejora de 0.093760
# Iteración 124: Mejora de 0.093514
# Iteración 125: Mejora de 0.093268
# Iteración 126: Mejora de 0.093023
# Iteración 127: Mejora de 0.092779
# Iteración 128: Mejora de 0.092535
# Iteración 129: Mejora de 0.092292
# Iteración 130: Mejora de 0.092050
# Iteración 131: Mejora de 0.091808
# Iteración 132: Mejora de 0.091567
# Iteración 133: Mejora de 0.091327
# Iteración 134: Mejora de 0.091087
# Iteración 135: Mejora de 0.090848
# Iteración 136: Mejora de 0.090609
# Iteración 137: Mejora de 0.090371
# Iteración 138: Mejora de 0.090134
# Iteración 139: Mejora de 0.089897
# Iteración 140: Mejora de 0.089661
# Iteración 141: Mejora de 0.089425
# Iteración 142: Mejora de 0.089191
# Iteración 143: Mejora de 0.088956
# Iteración 144: Mejora de 0.088723
# Iteración 145: Mejora de 0.088490
# Iteración 146: Mejora de 0.088257
# Iteración 147: Mejora de 0.088026
# Iteración 148: Mejora de 0.087794
# Iteración 149: Mejora de 0.087564
# Iteración 150: Mejora de 0.087334
# Iteración 151: Mejora de 0.087104
# Iteración 152: Mejora de 0.086876
# Iteración 153: Mejora de 0.086648
# Iteración 154: Mejora de 0.086420
# Iteración 155: Mejora de 0.086193
# Iteración 156: Mejora de 0.085967
# Iteración 157: Mejora de 0.085741
# Iteración 158: Mejora de 0.085516
# Iteración 159: Mejora de 0.085291
# Iteración 160: Mejora de 0.085067
# Iteración 161: Mejora de 0.084844
# Iteración 162: Mejora de 0.084621
# Iteración 163: Mejora de 0.084399
# Iteración 164: Mejora de 0.084177
# Iteración 165: Mejora de 0.083956
# Iteración 166: Mejora de 0.083736
# Iteración 167: Mejora de 0.083516
# Iteración 168: Mejora de 0.083296
# Iteración 169: Mejora de 0.083078
# Iteración 170: Mejora de 0.082859
# Iteración 171: Mejora de 0.082642
# Iteración 172: Mejora de 0.082425
# Iteración 173: Mejora de 0.082208
# Iteración 174: Mejora de 0.081992
# Iteración 175: Mejora de 0.081777
# Iteración 176: Mejora de 0.081562
# Iteración 177: Mejora de 0.081348
# Iteración 178: Mejora de 0.081134
# Iteración 179: Mejora de 0.080921
# Iteración 180: Mejora de 0.080709
# Iteración 181: Mejora de 0.080497
# Iteración 182: Mejora de 0.080285
# Iteración 183: Mejora de 0.080075
# Iteración 184: Mejora de 0.079864
# Iteración 185: Mejora de 0.079655
# Iteración 186: Mejora de 0.079445
# Iteración 187: Mejora de 0.079237
# Iteración 188: Mejora de 0.079029
# Iteración 189: Mejora de 0.078821
# Iteración 190: Mejora de 0.078614
# Iteración 191: Mejora de 0.078408
# Iteración 192: Mejora de 0.078202
# Iteración 193: Mejora de 0.077996
# Iteración 194: Mejora de 0.077792
# Iteración 195: Mejora de 0.077587
# Iteración 196: Mejora de 0.077383
# Iteración 197: Mejora de 0.077180
# Iteración 198: Mejora de 0.076978
# Iteración 199: Mejora de 0.076775
# Iteración 200: Mejora de 0.076574
# Iteración 201: Mejora de 0.076373
# Iteración 202: Mejora de 0.076172
# Iteración 203: Mejora de 0.075972
# Iteración 204: Mejora de 0.075773
# Iteración 205: Mejora de 0.075574
# Iteración 206: Mejora de 0.075375
# Iteración 207: Mejora de 0.075177
# Iteración 208: Mejora de 0.074980
# Iteración 209: Mejora de 0.074783
# Iteración 210: Mejora de 0.074586
# Iteración 211: Mejora de 0.074390
# Iteración 212: Mejora de 0.074195
# Iteración 213: Mejora de 0.074000
# Iteración 214: Mejora de 0.073806
# Iteración 215: Mejora de 0.073612
# Iteración 216: Mejora de 0.073419
# Iteración 217: Mejora de 0.073226
# Iteración 218: Mejora de 0.073034
# Iteración 219: Mejora de 0.072842
# Iteración 220: Mejora de 0.072651
# Iteración 221: Mejora de 0.072460
# Iteración 222: Mejora de 0.072269
# Iteración 223: Mejora de 0.072080
# Iteración 224: Mejora de 0.071890
# Iteración 225: Mejora de 0.071702
# Iteración 226: Mejora de 0.071513
# Iteración 227: Mejora de 0.071325
# Iteración 228: Mejora de 0.071138
# Iteración 229: Mejora de 0.070951
# Iteración 230: Mejora de 0.070765
# Iteración 231: Mejora de 0.070579
# Iteración 232: Mejora de 0.070394
# Iteración 233: Mejora de 0.070209
# Iteración 234: Mejora de 0.070025
# Iteración 235: Mejora de 0.069841
# Iteración 236: Mejora de 0.069657
# Iteración 237: Mejora de 0.069474
# Iteración 238: Mejora de 0.069292
# Iteración 239: Mejora de 0.069110
# Iteración 240: Mejora de 0.068928
# Iteración 241: Mejora de 0.068747
# Iteración 242: Mejora de 0.068567
# Iteración 243: Mejora de 0.068387
# Iteración 244: Mejora de 0.068207
# Iteración 245: Mejora de 0.068028
# Iteración 246: Mejora de 0.067849
# Iteración 247: Mejora de 0.067671
# Iteración 248: Mejora de 0.067493
# Iteración 249: Mejora de 0.067316
# Iteración 250: Mejora de 0.067139
# Iteración 251: Mejora de 0.066963
# Iteración 252: Mejora de 0.066787
# Iteración 253: Mejora de 0.066612
# Iteración 254: Mejora de 0.066437
# Iteración 255: Mejora de 0.066262
# Iteración 256: Mejora de 0.066088
# Iteración 257: Mejora de 0.065915
# Iteración 258: Mejora de 0.065742
# Iteración 259: Mejora de 0.065569
# Iteración 260: Mejora de 0.065397
# Iteración 261: Mejora de 0.065225
# Iteración 262: Mejora de 0.065054
# Iteración 263: Mejora de 0.064883
# Iteración 264: Mejora de 0.064713
# Iteración 265: Mejora de 0.064543
# Iteración 266: Mejora de 0.064373
# Iteración 267: Mejora de 0.064204
# Iteración 268: Mejora de 0.064035
# Iteración 269: Mejora de 0.063867
# Iteración 270: Mejora de 0.063700
# Iteración 271: Mejora de 0.063532
# Iteración 272: Mejora de 0.063365
# Iteración 273: Mejora de 0.063199
# Iteración 274: Mejora de 0.063033
# Iteración 275: Mejora de 0.062867
# Iteración 276: Mejora de 0.062702
# Iteración 277: Mejora de 0.062538
# Iteración 278: Mejora de 0.062373
# Iteración 279: Mejora de 0.062210
# Iteración 280: Mejora de 0.062046
# Iteración 281: Mejora de 0.061883
# Iteración 282: Mejora de 0.061721
# Iteración 283: Mejora de 0.061559
# Iteración 284: Mejora de 0.061397
# Iteración 285: Mejora de 0.061236
# Iteración 286: Mejora de 0.061075
# Iteración 287: Mejora de 0.060915
# Iteración 288: Mejora de 0.060755
# Iteración 289: Mejora de 0.060595
# Iteración 290: Mejora de 0.060436
# Iteración 291: Mejora de 0.060277
# Iteración 292: Mejora de 0.060119
# Iteración 293: Mejora de 0.059961
# Iteración 294: Mejora de 0.059804
# Iteración 295: Mejora de 0.059646
# Iteración 296: Mejora de 0.059490
# Iteración 297: Mejora de 0.059334
# Iteración 298: Mejora de 0.059178
# Iteración 299: Mejora de 0.059022
# Iteración 300: Mejora de 0.058867
# Iteración 301: Mejora de 0.058713
# Iteración 302: Mejora de 0.058559
# Iteración 303: Mejora de 0.058405
# Iteración 304: Mejora de 0.058251
# Iteración 305: Mejora de 0.058098
# Iteración 306: Mejora de 0.057946
# Iteración 307: Mejora de 0.057794
# Iteración 308: Mejora de 0.057642
# Iteración 309: Mejora de 0.057490
# Iteración 310: Mejora de 0.057340
# Iteración 311: Mejora de 0.057189
# Iteración 312: Mejora de 0.057039
# Iteración 313: Mejora de 0.056889
# Iteración 314: Mejora de 0.056740
# Iteración 315: Mejora de 0.056591
# Iteración 316: Mejora de 0.056442
# Iteración 317: Mejora de 0.056294
# Iteración 318: Mejora de 0.056146
# Iteración 319: Mejora de 0.055998
# Iteración 320: Mejora de 0.055851
# Iteración 321: Mejora de 0.055705
# Iteración 322: Mejora de 0.055558
# Iteración 323: Mejora de 0.055412
# Iteración 324: Mejora de 0.055267
# Iteración 325: Mejora de 0.055122
# Iteración 326: Mejora de 0.054977
# Iteración 327: Mejora de 0.054833
# Iteración 328: Mejora de 0.054689
# Iteración 329: Mejora de 0.054545
# Iteración 330: Mejora de 0.054402
# Iteración 331: Mejora de 0.054259
# Iteración 332: Mejora de 0.054116
# Iteración 333: Mejora de 0.053974
# Iteración 334: Mejora de 0.053833
# Iteración 335: Mejora de 0.053691
# Iteración 336: Mejora de 0.053550
# Iteración 337: Mejora de 0.053409
# Iteración 338: Mejora de 0.053269
# Iteración 339: Mejora de 0.053129
# Iteración 340: Mejora de 0.052990
# Iteración 341: Mejora de 0.052851
# Iteración 342: Mejora de 0.052712
# Iteración 343: Mejora de 0.052573
# Iteración 344: Mejora de 0.052435
# Iteración 345: Mejora de 0.052298
# Iteración 346: Mejora de 0.052160
# Iteración 347: Mejora de 0.052023
# Iteración 348: Mejora de 0.051887
# Iteración 349: Mejora de 0.051750
# Iteración 350: Mejora de 0.051615
# Iteración 351: Mejora de 0.051479
# Iteración 352: Mejora de 0.051344
# Iteración 353: Mejora de 0.051209
# Iteración 354: Mejora de 0.051074
# Iteración 355: Mejora de 0.050940
# Iteración 356: Mejora de 0.050807
# Iteración 357: Mejora de 0.050673
# Iteración 358: Mejora de 0.050540
# Iteración 359: Mejora de 0.050407
# Iteración 360: Mejora de 0.050275
# Iteración 361: Mejora de 0.050143
# Iteración 362: Mejora de 0.050011
# Iteración 363: Mejora de 0.049880
# Iteración 364: Mejora de 0.049749
# Iteración 365: Mejora de 0.049618
# Iteración 366: Mejora de 0.049488
# Iteración 367: Mejora de 0.049358
# Iteración 368: Mejora de 0.049228
# Iteración 369: Mejora de 0.049099
# Iteración 370: Mejora de 0.048970
# Iteración 371: Mejora de 0.048841
# Iteración 372: Mejora de 0.048713
# Iteración 373: Mejora de 0.048585
# Iteración 374: Mejora de 0.048458
# Iteración 375: Mejora de 0.048330
# Iteración 376: Mejora de 0.048203
# Iteración 377: Mejora de 0.048077
# Iteración 378: Mejora de 0.047951
# Iteración 379: Mejora de 0.047825
# Iteración 380: Mejora de 0.047699
# Iteración 381: Mejora de 0.047574
# Iteración 382: Mejora de 0.047449
# Iteración 383: Mejora de 0.047324
# Iteración 384: Mejora de 0.047200
# Iteración 385: Mejora de 0.047076
# Iteración 386: Mejora de 0.046952
# Iteración 387: Mejora de 0.046829
# Iteración 388: Mejora de 0.046706
# Iteración 389: Mejora de 0.046583
# Iteración 390: Mejora de 0.046461
# Iteración 391: Mejora de 0.046339
# Iteración 392: Mejora de 0.046217
# Iteración 393: Mejora de 0.046096
# Iteración 394: Mejora de 0.045975
# Iteración 395: Mejora de 0.045854
# Iteración 396: Mejora de 0.045734
# Iteración 397: Mejora de 0.045614
# Iteración 398: Mejora de 0.045494
# Iteración 399: Mejora de 0.045374
# Iteración 400: Mejora de 0.045255
# Iteración 401: Mejora de 0.045136
# Iteración 402: Mejora de 0.045018
# Iteración 403: Mejora de 0.044900
# Iteración 404: Mejora de 0.044782
# Iteración 405: Mejora de 0.044664
# Iteración 406: Mejora de 0.044547
# Iteración 407: Mejora de 0.044430
# Iteración 408: Mejora de 0.044313
# Iteración 409: Mejora de 0.044197
# Iteración 410: Mejora de 0.044081
# Iteración 411: Mejora de 0.043965
# Iteración 412: Mejora de 0.043849
# Iteración 413: Mejora de 0.043734
# Iteración 414: Mejora de 0.043619
# Iteración 415: Mejora de 0.043505
# Iteración 416: Mejora de 0.043391
# Iteración 417: Mejora de 0.043277
# Iteración 418: Mejora de 0.043163
# Iteración 419: Mejora de 0.043050
# Iteración 420: Mejora de 0.042937
# Iteración 421: Mejora de 0.042824
# Iteración 422: Mejora de 0.042711
# Iteración 423: Mejora de 0.042599
# Iteración 424: Mejora de 0.042487
# Iteración 425: Mejora de 0.042376
# Iteración 426: Mejora de 0.042264
# Iteración 427: Mejora de 0.042154
# Iteración 428: Mejora de 0.042043
# Iteración 429: Mejora de 0.041932
# Iteración 430: Mejora de 0.041822
# Iteración 431: Mejora de 0.041712
# Iteración 432: Mejora de 0.041603
# Iteración 433: Mejora de 0.041494
# Iteración 434: Mejora de 0.041385
# Iteración 435: Mejora de 0.041276
# Iteración 436: Mejora de 0.041168
# Iteración 437: Mejora de 0.041059
# Iteración 438: Mejora de 0.040952
# Iteración 439: Mejora de 0.040844
# Iteración 440: Mejora de 0.040737
# Iteración 441: Mejora de 0.040630
# Iteración 442: Mejora de 0.040523
# Iteración 443: Mejora de 0.040417
# Iteración 444: Mejora de 0.040311
# Iteración 445: Mejora de 0.040205
# Iteración 446: Mejora de 0.040099
# Iteración 447: Mejora de 0.039994
# Iteración 448: Mejora de 0.039889
# Iteración 449: Mejora de 0.039784
# Iteración 450: Mejora de 0.039680
# Iteración 451: Mejora de 0.039575
# Iteración 452: Mejora de 0.039471
# Iteración 453: Mejora de 0.039368
# Iteración 454: Mejora de 0.039264
# Iteración 455: Mejora de 0.039161
# Iteración 456: Mejora de 0.039058
# Iteración 457: Mejora de 0.038956
# Iteración 458: Mejora de 0.038853
# Iteración 459: Mejora de 0.038751
# Iteración 460: Mejora de 0.038650
# Iteración 461: Mejora de 0.038548
# Iteración 462: Mejora de 0.038447
# Iteración 463: Mejora de 0.038346
# Iteración 464: Mejora de 0.038245
# Iteración 465: Mejora de 0.038145
# Iteración 466: Mejora de 0.038045
# Iteración 467: Mejora de 0.037945
# Iteración 468: Mejora de 0.037845
# Iteración 469: Mejora de 0.037746
# Iteración 470: Mejora de 0.037647
# Iteración 471: Mejora de 0.037548
# Iteración 472: Mejora de 0.037449
# Iteración 473: Mejora de 0.037351
# Iteración 474: Mejora de 0.037253
# Iteración 475: Mejora de 0.037155
# Iteración 476: Mejora de 0.037057
# Iteración 477: Mejora de 0.036960
# Iteración 478: Mejora de 0.036863
# Iteración 479: Mejora de 0.036766
# Iteración 480: Mejora de 0.036669
# Iteración 481: Mejora de 0.036573
# Iteración 482: Mejora de 0.036477
# Iteración 483: Mejora de 0.036381
# Iteración 484: Mejora de 0.036286
# Iteración 485: Mejora de 0.036190
# Iteración 486: Mejora de 0.036095
# Iteración 487: Mejora de 0.036001
# Iteración 488: Mejora de 0.035906
# Iteración 489: Mejora de 0.035812
# Iteración 490: Mejora de 0.035718
# Iteración 491: Mejora de 0.035624
# Iteración 492: Mejora de 0.035530
# Iteración 493: Mejora de 0.035437
# Iteración 494: Mejora de 0.035344
# Iteración 495: Mejora de 0.035251
# Iteración 496: Mejora de 0.035159
# Iteración 497: Mejora de 0.035066
# Iteración 498: Mejora de 0.034974
# Iteración 499: Mejora de 0.034882
# Iteración 500: Mejora de 0.034791
# Iteración 501: Mejora de 0.034699
# Iteración 502: Mejora de 0.034608
# Iteración 503: Mejora de 0.034517
# Iteración 504: Mejora de 0.034427
# Iteración 505: Mejora de 0.034336
# Iteración 506: Mejora de 0.034246
# Iteración 507: Mejora de 0.034156
# Iteración 508: Mejora de 0.034066
# Iteración 509: Mejora de 0.033977
# Iteración 510: Mejora de 0.033888
# Iteración 511: Mejora de 0.033799
# Iteración 512: Mejora de 0.033710
# Iteración 513: Mejora de 0.033621
# Iteración 514: Mejora de 0.033533
# Iteración 515: Mejora de 0.033445
# Iteración 516: Mejora de 0.033357
# Iteración 517: Mejora de 0.033270
# Iteración 518: Mejora de 0.033182
# Iteración 519: Mejora de 0.033095
# Iteración 520: Mejora de 0.033008
# Iteración 521: Mejora de 0.032922
# Iteración 522: Mejora de 0.032835
# Iteración 523: Mejora de 0.032749
# Iteración 524: Mejora de 0.032663
# Iteración 525: Mejora de 0.032577
# Iteración 526: Mejora de 0.032492
# Iteración 527: Mejora de 0.032406
# Iteración 528: Mejora de 0.032321
# Iteración 529: Mejora de 0.032236
# Iteración 530: Mejora de 0.032152
# Iteración 531: Mejora de 0.032067
# Iteración 532: Mejora de 0.031983
# Iteración 533: Mejora de 0.031899
# Iteración 534: Mejora de 0.031815
# Iteración 535: Mejora de 0.031732
# Iteración 536: Mejora de 0.031648
# Iteración 537: Mejora de 0.031565
# Iteración 538: Mejora de 0.031482
# Iteración 539: Mejora de 0.031400
# Iteración 540: Mejora de 0.031317
# Iteración 541: Mejora de 0.031235
# Iteración 542: Mejora de 0.031153
# Iteración 543: Mejora de 0.031071
# Iteración 544: Mejora de 0.030989
# Iteración 545: Mejora de 0.030908
# Iteración 546: Mejora de 0.030827
# Iteración 547: Mejora de 0.030746
# Iteración 548: Mejora de 0.030665
# Iteración 549: Mejora de 0.030585
# Iteración 550: Mejora de 0.030504
# Iteración 551: Mejora de 0.030424
# Iteración 552: Mejora de 0.030344
# Iteración 553: Mejora de 0.030265
# Iteración 554: Mejora de 0.030185
# Iteración 555: Mejora de 0.030106
# Iteración 556: Mejora de 0.030027
# Iteración 557: Mejora de 0.029948
# Iteración 558: Mejora de 0.029869
# Iteración 559: Mejora de 0.029791
# Iteración 560: Mejora de 0.029713
# Iteración 561: Mejora de 0.029635
# Iteración 562: Mejora de 0.029557
# Iteración 563: Mejora de 0.029479
# Iteración 564: Mejora de 0.029402
# Iteración 565: Mejora de 0.029324
# Iteración 566: Mejora de 0.029247
# Iteración 567: Mejora de 0.029171
# Iteración 568: Mejora de 0.029094
# Iteración 569: Mejora de 0.029018
# Iteración 570: Mejora de 0.028941
# Iteración 571: Mejora de 0.028865
# Iteración 572: Mejora de 0.028790
# Iteración 573: Mejora de 0.028714
# Iteración 574: Mejora de 0.028639
# Iteración 575: Mejora de 0.028563
# Iteración 576: Mejora de 0.028488
# Iteración 577: Mejora de 0.028414
# Iteración 578: Mejora de 0.028339
# Iteración 579: Mejora de 0.028265
# Iteración 580: Mejora de 0.028190
# Iteración 581: Mejora de 0.028116
# Iteración 582: Mejora de 0.028042
# Iteración 583: Mejora de 0.027969
# Iteración 584: Mejora de 0.027895
# Iteración 585: Mejora de 0.027822
# Iteración 586: Mejora de 0.027749
# Iteración 587: Mejora de 0.027676
# Iteración 588: Mejora de 0.027603
# Iteración 589: Mejora de 0.027531
# Iteración 590: Mejora de 0.027459
# Iteración 591: Mejora de 0.027387
# Iteración 592: Mejora de 0.027315
# Iteración 593: Mejora de 0.027243
# Iteración 594: Mejora de 0.027171
# Iteración 595: Mejora de 0.027100
# Iteración 596: Mejora de 0.027029
# Iteración 597: Mejora de 0.026958
# Iteración 598: Mejora de 0.026887
# Iteración 599: Mejora de 0.026816
# Iteración 600: Mejora de 0.026746
# Iteración 601: Mejora de 0.026676
# Iteración 602: Mejora de 0.026606
# Iteración 603: Mejora de 0.026536
# Iteración 604: Mejora de 0.026466
# Iteración 605: Mejora de 0.026397
# Iteración 606: Mejora de 0.026327
# Iteración 607: Mejora de 0.026258
# Iteración 608: Mejora de 0.026189
# Iteración 609: Mejora de 0.026120
# Iteración 610: Mejora de 0.026052
# Iteración 611: Mejora de 0.025983
# Iteración 612: Mejora de 0.025915
# Iteración 613: Mejora de 0.025847
# Iteración 614: Mejora de 0.025779
# Iteración 615: Mejora de 0.025712
# Iteración 616: Mejora de 0.025644
# Iteración 617: Mejora de 0.025577
# Iteración 618: Mejora de 0.025509
# Iteración 619: Mejora de 0.025442
# Iteración 620: Mejora de 0.025376
# Iteración 621: Mejora de 0.025309
# Iteración 622: Mejora de 0.025243
# Iteración 623: Mejora de 0.025176
# Iteración 624: Mejora de 0.025110
# Iteración 625: Mejora de 0.025044
# Iteración 626: Mejora de 0.024978
# Iteración 627: Mejora de 0.024913
# Iteración 628: Mejora de 0.024847
# Iteración 629: Mejora de 0.024782
# Iteración 630: Mejora de 0.024717
# Iteración 631: Mejora de 0.024652
# Iteración 632: Mejora de 0.024587
# Iteración 633: Mejora de 0.024523
# Iteración 634: Mejora de 0.024458
# Iteración 635: Mejora de 0.024394
# Iteración 636: Mejora de 0.024330
# Iteración 637: Mejora de 0.024266
# Iteración 638: Mejora de 0.024203
# Iteración 639: Mejora de 0.024139
# Iteración 640: Mejora de 0.024076
# Iteración 641: Mejora de 0.024012
# Iteración 642: Mejora de 0.023949
# Iteración 643: Mejora de 0.023886
# Iteración 644: Mejora de 0.023824
# Iteración 645: Mejora de 0.023761
# Iteración 646: Mejora de 0.023699
# Iteración 647: Mejora de 0.023636
# Iteración 648: Mejora de 0.023574
# Iteración 649: Mejora de 0.023512
# Iteración 650: Mejora de 0.023451
# Iteración 651: Mejora de 0.023389
# Iteración 652: Mejora de 0.023328
# Iteración 653: Mejora de 0.023266
# Iteración 654: Mejora de 0.023205
# Iteración 655: Mejora de 0.023144
# Iteración 656: Mejora de 0.023084
# Iteración 657: Mejora de 0.023023
# Iteración 658: Mejora de 0.022963
# Iteración 659: Mejora de 0.022902
# Iteración 660: Mejora de 0.022842
# Iteración 661: Mejora de 0.022782
# Iteración 662: Mejora de 0.022722
# Iteración 663: Mejora de 0.022663
# Iteración 664: Mejora de 0.022603
# Iteración 665: Mejora de 0.022544
# Iteración 666: Mejora de 0.022484
# Iteración 667: Mejora de 0.022425
# Iteración 668: Mejora de 0.022367
# Iteración 669: Mejora de 0.022308
# Iteración 670: Mejora de 0.022249
# Iteración 671: Mejora de 0.022191
# Iteración 672: Mejora de 0.022132
# Iteración 673: Mejora de 0.022074
# Iteración 674: Mejora de 0.022016
# Iteración 675: Mejora de 0.021959
# Iteración 676: Mejora de 0.021901
# Iteración 677: Mejora de 0.021843
# Iteración 678: Mejora de 0.021786
# Iteración 679: Mejora de 0.021729
# Iteración 680: Mejora de 0.021672
# Iteración 681: Mejora de 0.021615
# Iteración 682: Mejora de 0.021558
# Iteración 683: Mejora de 0.021501
# Iteración 684: Mejora de 0.021445
# Iteración 685: Mejora de 0.021389
# Iteración 686: Mejora de 0.021332
# Iteración 687: Mejora de 0.021276
# Iteración 688: Mejora de 0.021221
# Iteración 689: Mejora de 0.021165
# Iteración 690: Mejora de 0.021109
# Iteración 691: Mejora de 0.021054
# Iteración 692: Mejora de 0.020999
# Iteración 693: Mejora de 0.020943
# Iteración 694: Mejora de 0.020888
# Iteración 695: Mejora de 0.020834
# Iteración 696: Mejora de 0.020779
# Iteración 697: Mejora de 0.020724
# Iteración 698: Mejora de 0.020670
# Iteración 699: Mejora de 0.020616
# Iteración 700: Mejora de 0.020561
# Iteración 701: Mejora de 0.020507
# Iteración 702: Mejora de 0.020454
# Iteración 703: Mejora de 0.020400
# Iteración 704: Mejora de 0.020346
# Iteración 705: Mejora de 0.020293
# Iteración 706: Mejora de 0.020240
# Iteración 707: Mejora de 0.020186
# Iteración 708: Mejora de 0.020133
# Iteración 709: Mejora de 0.020080
# Iteración 710: Mejora de 0.020028
# Iteración 711: Mejora de 0.019975
# Iteración 712: Mejora de 0.019923
# Iteración 713: Mejora de 0.019870
# Iteración 714: Mejora de 0.019818
# Iteración 715: Mejora de 0.019766
# Iteración 716: Mejora de 0.019714
# Iteración 717: Mejora de 0.019662
# Iteración 718: Mejora de 0.019611
# Iteración 719: Mejora de 0.019559
# Iteración 720: Mejora de 0.019508
# Iteración 721: Mejora de 0.019457
# Iteración 722: Mejora de 0.019406
# Iteración 723: Mejora de 0.019355
# Iteración 724: Mejora de 0.019304
# Iteración 725: Mejora de 0.019253
# Iteración 726: Mejora de 0.019203
# Iteración 727: Mejora de 0.019152
# Iteración 728: Mejora de 0.019102
# Iteración 729: Mejora de 0.019052
# Iteración 730: Mejora de 0.019002
# Iteración 731: Mejora de 0.018952
# Iteración 732: Mejora de 0.018902
# Iteración 733: Mejora de 0.018852
# Iteración 734: Mejora de 0.018803
# Iteración 735: Mejora de 0.018753
# Iteración 736: Mejora de 0.018704
# Iteración 737: Mejora de 0.018655
# Iteración 738: Mejora de 0.018606
# Iteración 739: Mejora de 0.018557
# Iteración 740: Mejora de 0.018508
# Iteración 741: Mejora de 0.018460
# Iteración 742: Mejora de 0.018411
# Iteración 743: Mejora de 0.018363
# Iteración 744: Mejora de 0.018315
# Iteración 745: Mejora de 0.018267
# Iteración 746: Mejora de 0.018219
# Iteración 747: Mejora de 0.018171
# Iteración 748: Mejora de 0.018123
# Iteración 749: Mejora de 0.018076
# Iteración 750: Mejora de 0.018028
# Iteración 751: Mejora de 0.017981
# Iteración 752: Mejora de 0.017934
# Iteración 753: Mejora de 0.017886
# Iteración 754: Mejora de 0.017839
# Iteración 755: Mejora de 0.017793
# Iteración 756: Mejora de 0.017746
# Iteración 757: Mejora de 0.017699
# Iteración 758: Mejora de 0.017653
# Iteración 759: Mejora de 0.017606
# Iteración 760: Mejora de 0.017560
# Iteración 761: Mejora de 0.017514
# Iteración 762: Mejora de 0.017468
# Iteración 763: Mejora de 0.017422
# Iteración 764: Mejora de 0.017376
# Iteración 765: Mejora de 0.017331
# Iteración 766: Mejora de 0.017285
# Iteración 767: Mejora de 0.017240
# Iteración 768: Mejora de 0.017195
# Iteración 769: Mejora de 0.017149
# Iteración 770: Mejora de 0.017104
# Iteración 771: Mejora de 0.017060
# Iteración 772: Mejora de 0.017015
# Iteración 773: Mejora de 0.016970
# Iteración 774: Mejora de 0.016925
# Iteración 775: Mejora de 0.016881
# Iteración 776: Mejora de 0.016837
# Iteración 777: Mejora de 0.016792
# Iteración 778: Mejora de 0.016748
# Iteración 779: Mejora de 0.016704
# Iteración 780: Mejora de 0.016661
# Iteración 781: Mejora de 0.016617
# Iteración 782: Mejora de 0.016573
# Iteración 783: Mejora de 0.016530
# Iteración 784: Mejora de 0.016486
# Iteración 785: Mejora de 0.016443
# Iteración 786: Mejora de 0.016400
# Iteración 787: Mejora de 0.016357
# Iteración 788: Mejora de 0.016314
# Iteración 789: Mejora de 0.016271
# Iteración 790: Mejora de 0.016228
# Iteración 791: Mejora de 0.016185
# Iteración 792: Mejora de 0.016143
# Iteración 793: Mejora de 0.016101
# Iteración 794: Mejora de 0.016058
# Iteración 795: Mejora de 0.016016
# Iteración 796: Mejora de 0.015974
# Iteración 797: Mejora de 0.015932
# Iteración 798: Mejora de 0.015890
# Iteración 799: Mejora de 0.015849
# Iteración 800: Mejora de 0.015807
# Iteración 801: Mejora de 0.015765
# Iteración 802: Mejora de 0.015724
# Iteración 803: Mejora de 0.015683
# Iteración 804: Mejora de 0.015642
# Iteración 805: Mejora de 0.015600
# Iteración 806: Mejora de 0.015559
# Iteración 807: Mejora de 0.015519
# Iteración 808: Mejora de 0.015478
# Iteración 809: Mejora de 0.015437
# Iteración 810: Mejora de 0.015397
# Iteración 811: Mejora de 0.015356
# Iteración 812: Mejora de 0.015316
# Iteración 813: Mejora de 0.015276
# Iteración 814: Mejora de 0.015236
# Iteración 815: Mejora de 0.015196
# Iteración 816: Mejora de 0.015156
# Iteración 817: Mejora de 0.015116
# Iteración 818: Mejora de 0.015076
# Iteración 819: Mejora de 0.015037
# Iteración 820: Mejora de 0.014997
# Iteración 821: Mejora de 0.014958
# Iteración 822: Mejora de 0.014918
# Iteración 823: Mejora de 0.014879
# Iteración 824: Mejora de 0.014840
# Iteración 825: Mejora de 0.014801
# Iteración 826: Mejora de 0.014762
# Iteración 827: Mejora de 0.014724
# Iteración 828: Mejora de 0.014685
# Iteración 829: Mejora de 0.014646
# Iteración 830: Mejora de 0.014608
# Iteración 831: Mejora de 0.014569
# Iteración 832: Mejora de 0.014531
# Iteración 833: Mejora de 0.014493
# Iteración 834: Mejora de 0.014455
# Iteración 835: Mejora de 0.014417
# Iteración 836: Mejora de 0.014379
# Iteración 837: Mejora de 0.014341
# Iteración 838: Mejora de 0.014304
# Iteración 839: Mejora de 0.014266
# Iteración 840: Mejora de 0.014229
# Iteración 841: Mejora de 0.014191
# Iteración 842: Mejora de 0.014154
# Iteración 843: Mejora de 0.014117
# Iteración 844: Mejora de 0.014080
# Iteración 845: Mejora de 0.014043
# Iteración 846: Mejora de 0.014006
# Iteración 847: Mejora de 0.013969
# Iteración 848: Mejora de 0.013932
# Iteración 849: Mejora de 0.013896
# Iteración 850: Mejora de 0.013859
# Iteración 851: Mejora de 0.013823
# Iteración 852: Mejora de 0.013787
# Iteración 853: Mejora de 0.013751
# Iteración 854: Mejora de 0.013714
# Iteración 855: Mejora de 0.013678
# Iteración 856: Mejora de 0.013642
# Iteración 857: Mejora de 0.013607
# Iteración 858: Mejora de 0.013571
# Iteración 859: Mejora de 0.013535
# Iteración 860: Mejora de 0.013500
# Iteración 861: Mejora de 0.013464
# Iteración 862: Mejora de 0.013429
# Iteración 863: Mejora de 0.013394
# Iteración 864: Mejora de 0.013358
# Iteración 865: Mejora de 0.013323
# Iteración 866: Mejora de 0.013288
# Iteración 867: Mejora de 0.013253
# Iteración 868: Mejora de 0.013219
# Iteración 869: Mejora de 0.013184
# Iteración 870: Mejora de 0.013149
# Iteración 871: Mejora de 0.013115
# Iteración 872: Mejora de 0.013080
# Iteración 873: Mejora de 0.013046
# Iteración 874: Mejora de 0.013012
# Iteración 875: Mejora de 0.012978
# Iteración 876: Mejora de 0.012943
# Iteración 877: Mejora de 0.012910
# Iteración 878: Mejora de 0.012876
# Iteración 879: Mejora de 0.012842
# Iteración 880: Mejora de 0.012808
# Iteración 881: Mejora de 0.012774
# Iteración 882: Mejora de 0.012741
# Iteración 883: Mejora de 0.012707
# Iteración 884: Mejora de 0.012674
# Iteración 885: Mejora de 0.012641
# Iteración 886: Mejora de 0.012608
# Iteración 887: Mejora de 0.012574
# Iteración 888: Mejora de 0.012541
# Iteración 889: Mejora de 0.012508
# Iteración 890: Mejora de 0.012476
# Iteración 891: Mejora de 0.012443
# Iteración 892: Mejora de 0.012410
# Iteración 893: Mejora de 0.012378
# Iteración 894: Mejora de 0.012345
# Iteración 895: Mejora de 0.012313
# Iteración 896: Mejora de 0.012280
# Iteración 897: Mejora de 0.012248
# Iteración 898: Mejora de 0.012216
# Iteración 899: Mejora de 0.012184
# Iteración 900: Mejora de 0.012152
# Iteración 901: Mejora de 0.012120
# Iteración 902: Mejora de 0.012088
# Iteración 903: Mejora de 0.012056
# Iteración 904: Mejora de 0.012025
# Iteración 905: Mejora de 0.011993
# Iteración 906: Mejora de 0.011962
# Iteración 907: Mejora de 0.011930
# Iteración 908: Mejora de 0.011899
# Iteración 909: Mejora de 0.011868
# Iteración 910: Mejora de 0.011836
# Iteración 911: Mejora de 0.011805
# Iteración 912: Mejora de 0.011774
# Iteración 913: Mejora de 0.011743
# Iteración 914: Mejora de 0.011713
# Iteración 915: Mejora de 0.011682
# Iteración 916: Mejora de 0.011651
# Iteración 917: Mejora de 0.011621
# Iteración 918: Mejora de 0.011590
# Iteración 919: Mejora de 0.011560
# Iteración 920: Mejora de 0.011529
# Iteración 921: Mejora de 0.011499
# Iteración 922: Mejora de 0.011469
# Iteración 923: Mejora de 0.011439
# Iteración 924: Mejora de 0.011409
# Iteración 925: Mejora de 0.011379
# Iteración 926: Mejora de 0.011349
# Iteración 927: Mejora de 0.011319
# Iteración 928: Mejora de 0.011289
# Iteración 929: Mejora de 0.011260
# Iteración 930: Mejora de 0.011230
# Iteración 931: Mejora de 0.011201
# Iteración 932: Mejora de 0.011171
# Iteración 933: Mejora de 0.011142
# Iteración 934: Mejora de 0.011113
# Iteración 935: Mejora de 0.011083
# Iteración 936: Mejora de 0.011054
# Iteración 937: Mejora de 0.011025
# Iteración 938: Mejora de 0.010996
# Iteración 939: Mejora de 0.010967
# Iteración 940: Mejora de 0.010939
# Iteración 941: Mejora de 0.010910
# Iteración 942: Mejora de 0.010881
# Iteración 943: Mejora de 0.010853
# Iteración 944: Mejora de 0.010824
# Iteración 945: Mejora de 0.010796
# Iteración 946: Mejora de 0.010767
# Iteración 947: Mejora de 0.010739
# Iteración 948: Mejora de 0.010711
# Iteración 949: Mejora de 0.010683
# Iteración 950: Mejora de 0.010655
# Iteración 951: Mejora de 0.010627
# Iteración 952: Mejora de 0.010599
# Iteración 953: Mejora de 0.010571
# Iteración 954: Mejora de 0.010543
# Iteración 955: Mejora de 0.010515
# Iteración 956: Mejora de 0.010488
# Iteración 957: Mejora de 0.010460
# Iteración 958: Mejora de 0.010433
# Iteración 959: Mejora de 0.010405
# Iteración 960: Mejora de 0.010378
# Iteración 961: Mejora de 0.010351
# Iteración 962: Mejora de 0.010324
# Iteración 963: Mejora de 0.010297
# Iteración 964: Mejora de 0.010270
# Iteración 965: Mejora de 0.010243
# Iteración 966: Mejora de 0.010216
# Iteración 967: Mejora de 0.010189
# Iteración 968: Mejora de 0.010162
# Iteración 969: Mejora de 0.010135
# Iteración 970: Mejora de 0.010109
# Iteración 971: Mejora de 0.010082
# Iteración 972: Mejora de 0.010056
# Iteración 973: Mejora de 0.010029
# Iteración 974: Mejora de 0.010003
# Iteración 975: Mejora de 0.009977
# Iteración 976: Mejora de 0.009951
# Iteración 977: Mejora de 0.009924
# Iteración 978: Mejora de 0.009898
# Iteración 979: Mejora de 0.009872
# Iteración 980: Mejora de 0.009846
# Iteración 981: Mejora de 0.009821
# Iteración 982: Mejora de 0.009795
# Iteración 983: Mejora de 0.009769
# Iteración 984: Mejora de 0.009743
# Iteración 985: Mejora de 0.009718
# Iteración 986: Mejora de 0.009692
# Iteración 987: Mejora de 0.009667
# Iteración 988: Mejora de 0.009641
# Iteración 989: Mejora de 0.009616
# Iteración 990: Mejora de 0.009591
# Iteración 991: Mejora de 0.009566
# Iteración 992: Mejora de 0.009541
# Iteración 993: Mejora de 0.009515
# Iteración 994: Mejora de 0.009491
# Iteración 995: Mejora de 0.009466
# Iteración 996: Mejora de 0.009441
# Iteración 997: Mejora de 0.009416
# Iteración 998: Mejora de 0.009391
# Iteración 999: Mejora de 0.009367
# Iteración 1000: Mejora de 0.009342
# Iteración 1001: Mejora de 0.009317
# Iteración 1002: Mejora de 0.009293
# Iteración 1003: Mejora de 0.009269
# Iteración 1004: Mejora de 0.009244
# Iteración 1005: Mejora de 0.009220
# Iteración 1006: Mejora de 0.009196
# Iteración 1007: Mejora de 0.009172
# Iteración 1008: Mejora de 0.009147
# Iteración 1009: Mejora de 0.009123
# Iteración 1010: Mejora de 0.009099
# Iteración 1011: Mejora de 0.009076
# Iteración 1012: Mejora de 0.009052
# Iteración 1013: Mejora de 0.009028
# Iteración 1014: Mejora de 0.009004
# Iteración 1015: Mejora de 0.008981
# Iteración 1016: Mejora de 0.008957
# Iteración 1017: Mejora de 0.008934
# Iteración 1018: Mejora de 0.008910
# Iteración 1019: Mejora de 0.008887
# Iteración 1020: Mejora de 0.008863
# Iteración 1021: Mejora de 0.008840
# Iteración 1022: Mejora de 0.008817
# Iteración 1023: Mejora de 0.008794
# Iteración 1024: Mejora de 0.008771
# Iteración 1025: Mejora de 0.008748
# Iteración 1026: Mejora de 0.008725
# Iteración 1027: Mejora de 0.008702
# Iteración 1028: Mejora de 0.008679
# Iteración 1029: Mejora de 0.008656
# Iteración 1030: Mejora de 0.008633
# Iteración 1031: Mejora de 0.008611
# Iteración 1032: Mejora de 0.008588
# Iteración 1033: Mejora de 0.008565
# Iteración 1034: Mejora de 0.008543
# Iteración 1035: Mejora de 0.008520
# Iteración 1036: Mejora de 0.008498
# Iteración 1037: Mejora de 0.008476
# Iteración 1038: Mejora de 0.008454
# Iteración 1039: Mejora de 0.008431
# Iteración 1040: Mejora de 0.008409
# Iteración 1041: Mejora de 0.008387
# Iteración 1042: Mejora de 0.008365
# Iteración 1043: Mejora de 0.008343
# Iteración 1044: Mejora de 0.008321
# Iteración 1045: Mejora de 0.008299
# Iteración 1046: Mejora de 0.008278
# Iteración 1047: Mejora de 0.008256
# Iteración 1048: Mejora de 0.008234
# Iteración 1049: Mejora de 0.008213
# Iteración 1050: Mejora de 0.008191
# Iteración 1051: Mejora de 0.008169
# Iteración 1052: Mejora de 0.008148
# Iteración 1053: Mejora de 0.008127
# Iteración 1054: Mejora de 0.008105
# Iteración 1055: Mejora de 0.008084
# Iteración 1056: Mejora de 0.008063
# Iteración 1057: Mejora de 0.008042
# Iteración 1058: Mejora de 0.008020
# Iteración 1059: Mejora de 0.007999
# Iteración 1060: Mejora de 0.007978
# Iteración 1061: Mejora de 0.007957
# Iteración 1062: Mejora de 0.007937
# Iteración 1063: Mejora de 0.007916
# Iteración 1064: Mejora de 0.007895
# Iteración 1065: Mejora de 0.007874
# Iteración 1066: Mejora de 0.007853
# Iteración 1067: Mejora de 0.007833
# Iteración 1068: Mejora de 0.007812
# Iteración 1069: Mejora de 0.007792
# Iteración 1070: Mejora de 0.007771
# Iteración 1071: Mejora de 0.007751
# Iteración 1072: Mejora de 0.007731
# Iteración 1073: Mejora de 0.007710
# Iteración 1074: Mejora de 0.007690
# Iteración 1075: Mejora de 0.007670
# Iteración 1076: Mejora de 0.007650
# Iteración 1077: Mejora de 0.007630
# Iteración 1078: Mejora de 0.007610
# Iteración 1079: Mejora de 0.007590
# Iteración 1080: Mejora de 0.007570
# Iteración 1081: Mejora de 0.007550
# Iteración 1082: Mejora de 0.007530
# Iteración 1083: Mejora de 0.007510
# Iteración 1084: Mejora de 0.007490
# Iteración 1085: Mejora de 0.007471
# Iteración 1086: Mejora de 0.007451
# Iteración 1087: Mejora de 0.007432
# Iteración 1088: Mejora de 0.007412
# Iteración 1089: Mejora de 0.007393
# Iteración 1090: Mejora de 0.007373
# Iteración 1091: Mejora de 0.007354
# Iteración 1092: Mejora de 0.007334
# Iteración 1093: Mejora de 0.007315
# Iteración 1094: Mejora de 0.007296
# Iteración 1095: Mejora de 0.007277
# Iteración 1096: Mejora de 0.007258
# Iteración 1097: Mejora de 0.007239
# Iteración 1098: Mejora de 0.007220
# Iteración 1099: Mejora de 0.007201
# Iteración 1100: Mejora de 0.007182
# Iteración 1101: Mejora de 0.007163
# Iteración 1102: Mejora de 0.007144
# Iteración 1103: Mejora de 0.007125
# Iteración 1104: Mejora de 0.007107
# Iteración 1105: Mejora de 0.007088
# Iteración 1106: Mejora de 0.007069
# Iteración 1107: Mejora de 0.007051
# Iteración 1108: Mejora de 0.007032
# Iteración 1109: Mejora de 0.007014
# Iteración 1110: Mejora de 0.006995
# Iteración 1111: Mejora de 0.006977
# Iteración 1112: Mejora de 0.006959
# Iteración 1113: Mejora de 0.006940
# Iteración 1114: Mejora de 0.006922
# Iteración 1115: Mejora de 0.006904
# Iteración 1116: Mejora de 0.006886
# Iteración 1117: Mejora de 0.006868
# Iteración 1118: Mejora de 0.006850
# Iteración 1119: Mejora de 0.006832
# Iteración 1120: Mejora de 0.006814
# Iteración 1121: Mejora de 0.006796
# Iteración 1122: Mejora de 0.006778
# Iteración 1123: Mejora de 0.006760
# Iteración 1124: Mejora de 0.006743
# Iteración 1125: Mejora de 0.006725
# Iteración 1126: Mejora de 0.006707
# Iteración 1127: Mejora de 0.006690
# Iteración 1128: Mejora de 0.006672
# Iteración 1129: Mejora de 0.006654
# Iteración 1130: Mejora de 0.006637
# Iteración 1131: Mejora de 0.006620
# Iteración 1132: Mejora de 0.006602
# Iteración 1133: Mejora de 0.006585
# Iteración 1134: Mejora de 0.006568
# Iteración 1135: Mejora de 0.006550
# Iteración 1136: Mejora de 0.006533
# Iteración 1137: Mejora de 0.006516
# Iteración 1138: Mejora de 0.006499
# Iteración 1139: Mejora de 0.006482
# Iteración 1140: Mejora de 0.006465
# Iteración 1141: Mejora de 0.006448
# Iteración 1142: Mejora de 0.006431
# Iteración 1143: Mejora de 0.006414
# Iteración 1144: Mejora de 0.006397
# Iteración 1145: Mejora de 0.006380
# Iteración 1146: Mejora de 0.006364
# Iteración 1147: Mejora de 0.006347
# Iteración 1148: Mejora de 0.006330
# Iteración 1149: Mejora de 0.006314
# Iteración 1150: Mejora de 0.006297
# Iteración 1151: Mejora de 0.006280
# Iteración 1152: Mejora de 0.006264
# Iteración 1153: Mejora de 0.006247
# Iteración 1154: Mejora de 0.006231
# Iteración 1155: Mejora de 0.006215
# Iteración 1156: Mejora de 0.006198
# Iteración 1157: Mejora de 0.006182
# Iteración 1158: Mejora de 0.006166
# Iteración 1159: Mejora de 0.006150
# Iteración 1160: Mejora de 0.006133
# Iteración 1161: Mejora de 0.006117
# Iteración 1162: Mejora de 0.006101
# Iteración 1163: Mejora de 0.006085
# Iteración 1164: Mejora de 0.006069
# Iteración 1165: Mejora de 0.006053
# Iteración 1166: Mejora de 0.006037
# Iteración 1167: Mejora de 0.006022
# Iteración 1168: Mejora de 0.006006
# Iteración 1169: Mejora de 0.005990
# Iteración 1170: Mejora de 0.005974
# Iteración 1171: Mejora de 0.005959
# Iteración 1172: Mejora de 0.005943
# Iteración 1173: Mejora de 0.005927
# Iteración 1174: Mejora de 0.005912
# Iteración 1175: Mejora de 0.005896
# Iteración 1176: Mejora de 0.005881
# Iteración 1177: Mejora de 0.005865
# Iteración 1178: Mejora de 0.005850
# Iteración 1179: Mejora de 0.005835
# Iteración 1180: Mejora de 0.005819
# Iteración 1181: Mejora de 0.005804
# Iteración 1182: Mejora de 0.005789
# Iteración 1183: Mejora de 0.005774
# Iteración 1184: Mejora de 0.005758
# Iteración 1185: Mejora de 0.005743
# Iteración 1186: Mejora de 0.005728
# Iteración 1187: Mejora de 0.005713
# Iteración 1188: Mejora de 0.005698
# Iteración 1189: Mejora de 0.005683
# Iteración 1190: Mejora de 0.005668
# Iteración 1191: Mejora de 0.005653
# Iteración 1192: Mejora de 0.005638
# Iteración 1193: Mejora de 0.005624
# Iteración 1194: Mejora de 0.005609
# Iteración 1195: Mejora de 0.005594
# Iteración 1196: Mejora de 0.005579
# Iteración 1197: Mejora de 0.005565
# Iteración 1198: Mejora de 0.005550
# Iteración 1199: Mejora de 0.005536
# Iteración 1200: Mejora de 0.005521
# Iteración 1201: Mejora de 0.005507
# Iteración 1202: Mejora de 0.005492
# Iteración 1203: Mejora de 0.005478
# Iteración 1204: Mejora de 0.005463
# Iteración 1205: Mejora de 0.005449
# Iteración 1206: Mejora de 0.005435
# Iteración 1207: Mejora de 0.005420
# Iteración 1208: Mejora de 0.005406
# Iteración 1209: Mejora de 0.005392
# Iteración 1210: Mejora de 0.005378
# Iteración 1211: Mejora de 0.005364
# Iteración 1212: Mejora de 0.005350
# Iteración 1213: Mejora de 0.005336
# Iteración 1214: Mejora de 0.005322
# Iteración 1215: Mejora de 0.005308
# Iteración 1216: Mejora de 0.005294
# Iteración 1217: Mejora de 0.005280
# Iteración 1218: Mejora de 0.005266
# Iteración 1219: Mejora de 0.005252
# Iteración 1220: Mejora de 0.005238
# Iteración 1221: Mejora de 0.005224
# Iteración 1222: Mejora de 0.005211
# Iteración 1223: Mejora de 0.005197
# Iteración 1224: Mejora de 0.005183
# Iteración 1225: Mejora de 0.005170
# Iteración 1226: Mejora de 0.005156
# Iteración 1227: Mejora de 0.005143
# Iteración 1228: Mejora de 0.005129
# Iteración 1229: Mejora de 0.005116
# Iteración 1230: Mejora de 0.005102
# Iteración 1231: Mejora de 0.005089
# Iteración 1232: Mejora de 0.005076
# Iteración 1233: Mejora de 0.005062
# Iteración 1234: Mejora de 0.005049
# Iteración 1235: Mejora de 0.005036
# Iteración 1236: Mejora de 0.005022
# Iteración 1237: Mejora de 0.005009
# Iteración 1238: Mejora de 0.004996
# Iteración 1239: Mejora de 0.004983
# Iteración 1240: Mejora de 0.004970
# Iteración 1241: Mejora de 0.004957
# Iteración 1242: Mejora de 0.004944
# Iteración 1243: Mejora de 0.004931
# Iteración 1244: Mejora de 0.004918
# Iteración 1245: Mejora de 0.004905
# Iteración 1246: Mejora de 0.004892
# Iteración 1247: Mejora de 0.004879
# Iteración 1248: Mejora de 0.004866
# Iteración 1249: Mejora de 0.004854
# Iteración 1250: Mejora de 0.004841
# Iteración 1251: Mejora de 0.004828
# Iteración 1252: Mejora de 0.004815
# Iteración 1253: Mejora de 0.004803
# Iteración 1254: Mejora de 0.004790
# Iteración 1255: Mejora de 0.004778
# Iteración 1256: Mejora de 0.004765
# Iteración 1257: Mejora de 0.004753
# Iteración 1258: Mejora de 0.004740
# Iteración 1259: Mejora de 0.004728
# Iteración 1260: Mejora de 0.004715
# Iteración 1261: Mejora de 0.004703
# Iteración 1262: Mejora de 0.004690
# Iteración 1263: Mejora de 0.004678
# Iteración 1264: Mejora de 0.004666
# Iteración 1265: Mejora de 0.004654
# Iteración 1266: Mejora de 0.004641
# Iteración 1267: Mejora de 0.004629
# Iteración 1268: Mejora de 0.004617
# Iteración 1269: Mejora de 0.004605
# Iteración 1270: Mejora de 0.004593
# Iteración 1271: Mejora de 0.004581
# Iteración 1272: Mejora de 0.004569
# Iteración 1273: Mejora de 0.004557
# Iteración 1274: Mejora de 0.004545
# Iteración 1275: Mejora de 0.004533
# Iteración 1276: Mejora de 0.004521
# Iteración 1277: Mejora de 0.004509
# Iteración 1278: Mejora de 0.004497
# Iteración 1279: Mejora de 0.004485
# Iteración 1280: Mejora de 0.004474
# Iteración 1281: Mejora de 0.004462
# Iteración 1282: Mejora de 0.004450
# Iteración 1283: Mejora de 0.004438
# Iteración 1284: Mejora de 0.004427
# Iteración 1285: Mejora de 0.004415
# Iteración 1286: Mejora de 0.004404
# Iteración 1287: Mejora de 0.004392
# Iteración 1288: Mejora de 0.004381
# Iteración 1289: Mejora de 0.004369
# Iteración 1290: Mejora de 0.004358
# Iteración 1291: Mejora de 0.004346
# Iteración 1292: Mejora de 0.004335
# Iteración 1293: Mejora de 0.004323
# Iteración 1294: Mejora de 0.004312
# Iteración 1295: Mejora de 0.004301
# Iteración 1296: Mejora de 0.004289
# Iteración 1297: Mejora de 0.004278
# Iteración 1298: Mejora de 0.004267
# Iteración 1299: Mejora de 0.004256
# Iteración 1300: Mejora de 0.004244
# Iteración 1301: Mejora de 0.004233
# Iteración 1302: Mejora de 0.004222
# Iteración 1303: Mejora de 0.004211
# Iteración 1304: Mejora de 0.004200
# Iteración 1305: Mejora de 0.004189
# Iteración 1306: Mejora de 0.004178
# Iteración 1307: Mejora de 0.004167
# Iteración 1308: Mejora de 0.004156
# Iteración 1309: Mejora de 0.004145
# Iteración 1310: Mejora de 0.004134
# Iteración 1311: Mejora de 0.004123
# Iteración 1312: Mejora de 0.004113
# Iteración 1313: Mejora de 0.004102
# Iteración 1314: Mejora de 0.004091
# Iteración 1315: Mejora de 0.004080
# Iteración 1316: Mejora de 0.004070
# Iteración 1317: Mejora de 0.004059
# Iteración 1318: Mejora de 0.004048
# Iteración 1319: Mejora de 0.004038
# Iteración 1320: Mejora de 0.004027
# Iteración 1321: Mejora de 0.004016
# Iteración 1322: Mejora de 0.004006
# Iteración 1323: Mejora de 0.003995
# Iteración 1324: Mejora de 0.003985
# Iteración 1325: Mejora de 0.003974
# Iteración 1326: Mejora de 0.003964
# Iteración 1327: Mejora de 0.003954
# Iteración 1328: Mejora de 0.003943
# Iteración 1329: Mejora de 0.003933
# Iteración 1330: Mejora de 0.003922
# Iteración 1331: Mejora de 0.003912
# Iteración 1332: Mejora de 0.003902
# Iteración 1333: Mejora de 0.003892
# Iteración 1334: Mejora de 0.003881
# Iteración 1335: Mejora de 0.003871
# Iteración 1336: Mejora de 0.003861
# Iteración 1337: Mejora de 0.003851
# Iteración 1338: Mejora de 0.003841
# Iteración 1339: Mejora de 0.003831
# Iteración 1340: Mejora de 0.003821
# Iteración 1341: Mejora de 0.003811
# Iteración 1342: Mejora de 0.003801
# Iteración 1343: Mejora de 0.003791
# Iteración 1344: Mejora de 0.003781
# Iteración 1345: Mejora de 0.003771
# Iteración 1346: Mejora de 0.003761
# Iteración 1347: Mejora de 0.003751
# Iteración 1348: Mejora de 0.003741
# Iteración 1349: Mejora de 0.003731
# Iteración 1350: Mejora de 0.003721
# Iteración 1351: Mejora de 0.003712
# Iteración 1352: Mejora de 0.003702
# Iteración 1353: Mejora de 0.003692
# Iteración 1354: Mejora de 0.003683
# Iteración 1355: Mejora de 0.003673
# Iteración 1356: Mejora de 0.003663
# Iteración 1357: Mejora de 0.003654
# Iteración 1358: Mejora de 0.003644
# Iteración 1359: Mejora de 0.003634
# Iteración 1360: Mejora de 0.003625
# Iteración 1361: Mejora de 0.003615
# Iteración 1362: Mejora de 0.003606
# Iteración 1363: Mejora de 0.003596
# Iteración 1364: Mejora de 0.003587
# Iteración 1365: Mejora de 0.003578
# Iteración 1366: Mejora de 0.003568
# Iteración 1367: Mejora de 0.003559
# Iteración 1368: Mejora de 0.003549
# Iteración 1369: Mejora de 0.003540
# Iteración 1370: Mejora de 0.003531
# Iteración 1371: Mejora de 0.003522
# Iteración 1372: Mejora de 0.003512
# Iteración 1373: Mejora de 0.003503
# Iteración 1374: Mejora de 0.003494
# Iteración 1375: Mejora de 0.003485
# Iteración 1376: Mejora de 0.003476
# Iteración 1377: Mejora de 0.003466
# Iteración 1378: Mejora de 0.003457
# Iteración 1379: Mejora de 0.003448
# Iteración 1380: Mejora de 0.003439
# Iteración 1381: Mejora de 0.003430
# Iteración 1382: Mejora de 0.003421
# Iteración 1383: Mejora de 0.003412
# Iteración 1384: Mejora de 0.003403
# Iteración 1385: Mejora de 0.003394
# Iteración 1386: Mejora de 0.003385
# Iteración 1387: Mejora de 0.003376
# Iteración 1388: Mejora de 0.003368
# Iteración 1389: Mejora de 0.003359
# Iteración 1390: Mejora de 0.003350
# Iteración 1391: Mejora de 0.003341
# Iteración 1392: Mejora de 0.003332
# Iteración 1393: Mejora de 0.003324
# Iteración 1394: Mejora de 0.003315
# Iteración 1395: Mejora de 0.003306
# Iteración 1396: Mejora de 0.003297
# Iteración 1397: Mejora de 0.003289
# Iteración 1398: Mejora de 0.003280
# Iteración 1399: Mejora de 0.003272
# Iteración 1400: Mejora de 0.003263
# Iteración 1401: Mejora de 0.003254
# Iteración 1402: Mejora de 0.003246
# ...
# Iteración 2275: Mejora de 0.000327
# Iteración 2276: Mejora de 0.000326
# Iteración 2277: Mejora de 0.000325
# Iteración 2278: Mejora de 0.000324
# Iteración 2279: Mejora de 0.000323
# Iteración 2280: Mejora de 0.000323
# Iteración 2281: Mejora de 0.000322
# Iteración 2282: Mejora de 0.000321
# Iteración 2283: Mejora de 0.000320
# Iteración 2284: Mejora de 0.000319
# Iteración 2285: Mejora de 0.000318
# Iteración 2286: Mejora de 0.000318
# Iteración 2287: Mejora de 0.000317
# Iteración 2288: Mejora de 0.000316
# Iteración 2289: Mejora de 0.000315
# Iteración 2290: Mejora de 0.000314
# Iteración 2291: Mejora de 0.000313
# Iteración 2292: Mejora de 0.000313
# Iteración 2293: Mejora de 0.000312
# Iteración 2294: Mejora de 0.000311
# Iteración 2295: Mejora de 0.000310
# Iteración 2296: Mejora de 0.000309
# Iteración 2297: Mejora de 0.000308
# Iteración 2298: Mejora de 0.000308
# Iteración 2299: Mejora de 0.000307
# Iteración 2300: Mejora de 0.000306
# Iteración 2301: Mejora de 0.000305
# Iteración 2302: Mejora de 0.000304
# Iteración 2303: Mejora de 0.000304
# Iteración 2304: Mejora de 0.000303
# Iteración 2305: Mejora de 0.000302
# Iteración 2306: Mejora de 0.000301
# Iteración 2307: Mejora de 0.000300
# Iteración 2308: Mejora de 0.000300
# Iteración 2309: Mejora de 0.000299
# Iteración 2310: Mejora de 0.000298
# Iteración 2311: Mejora de 0.000297
# Iteración 2312: Mejora de 0.000297
# Iteración 2313: Mejora de 0.000296
# Iteración 2314: Mejora de 0.000295
# Iteración 2315: Mejora de 0.000294
# Iteración 2316: Mejora de 0.000293
# Iteración 2317: Mejora de 0.000293
# Iteración 2318: Mejora de 0.000292
# Iteración 2319: Mejora de 0.000291
# Iteración 2320: Mejora de 0.000290
# Iteración 2321: Mejora de 0.000290
# Iteración 2322: Mejora de 0.000289
# Iteración 2323: Mejora de 0.000288
# Iteración 2324: Mejora de 0.000287
# Iteración 2325: Mejora de 0.000287
# Iteración 2326: Mejora de 0.000286
# Iteración 2327: Mejora de 0.000285
# Iteración 2328: Mejora de 0.000284
# Iteración 2329: Mejora de 0.000284
# Iteración 2330: Mejora de 0.000283
# Iteración 2331: Mejora de 0.000282
# Iteración 2332: Mejora de 0.000281
# Iteración 2333: Mejora de 0.000281
# Iteración 2334: Mejora de 0.000280
# Iteración 2335: Mejora de 0.000279
# Iteración 2336: Mejora de 0.000278
# Iteración 2337: Mejora de 0.000278
# Iteración 2338: Mejora de 0.000277
# Iteración 2339: Mejora de 0.000276
# Iteración 2340: Mejora de 0.000275
# Iteración 2341: Mejora de 0.000275
# Iteración 2342: Mejora de 0.000274
# Iteración 2343: Mejora de 0.000273
# Iteración 2344: Mejora de 0.000273
# Iteración 2345: Mejora de 0.000272
# Iteración 2346: Mejora de 0.000271
# Iteración 2347: Mejora de 0.000270
# Iteración 2348: Mejora de 0.000270
# Iteración 2349: Mejora de 0.000269
# Iteración 2350: Mejora de 0.000268
# Iteración 2351: Mejora de 0.000268
# Iteración 2352: Mejora de 0.000267
# Iteración 2353: Mejora de 0.000266
# Iteración 2354: Mejora de 0.000266
# Iteración 2355: Mejora de 0.000265
# Iteración 2356: Mejora de 0.000264
# Iteración 2357: Mejora de 0.000263
# Iteración 2358: Mejora de 0.000263
# Iteración 2359: Mejora de 0.000262
# Iteración 2360: Mejora de 0.000261
# Iteración 2361: Mejora de 0.000261
# Iteración 2362: Mejora de 0.000260
# Iteración 2363: Mejora de 0.000259
# Iteración 2364: Mejora de 0.000259
# Iteración 2365: Mejora de 0.000258
# Iteración 2366: Mejora de 0.000257
# Iteración 2367: Mejora de 0.000257
# Iteración 2368: Mejora de 0.000256
# Iteración 2369: Mejora de 0.000255
# Iteración 2370: Mejora de 0.000255
# Iteración 2371: Mejora de 0.000254
# Iteración 2372: Mejora de 0.000253
# Iteración 2373: Mejora de 0.000253
# Iteración 2374: Mejora de 0.000252
# Iteración 2375: Mejora de 0.000251
# Iteración 2376: Mejora de 0.000251
# Iteración 2377: Mejora de 0.000250
# Iteración 2378: Mejora de 0.000249
# Iteración 2379: Mejora de 0.000249
# Iteración 2380: Mejora de 0.000248
# Iteración 2381: Mejora de 0.000247
# Iteración 2382: Mejora de 0.000247
# Iteración 2383: Mejora de 0.000246
# Iteración 2384: Mejora de 0.000245
# Iteración 2385: Mejora de 0.000245
# Iteración 2386: Mejora de 0.000244
# Iteración 2387: Mejora de 0.000243
# Iteración 2388: Mejora de 0.000243
# Iteración 2389: Mejora de 0.000242
# Iteración 2390: Mejora de 0.000242
# Iteración 2391: Mejora de 0.000241
# Iteración 2392: Mejora de 0.000240
# Iteración 2393: Mejora de 0.000240
# Iteración 2394: Mejora de 0.000239
# Iteración 2395: Mejora de 0.000238
# Iteración 2396: Mejora de 0.000238
# Iteración 2397: Mejora de 0.000237
# Iteración 2398: Mejora de 0.000237
# Iteración 2399: Mejora de 0.000236
# Iteración 2400: Mejora de 0.000235
# Iteración 2401: Mejora de 0.000235
# Iteración 2402: Mejora de 0.000234
# Iteración 2403: Mejora de 0.000233
# Iteración 2404: Mejora de 0.000233
# Iteración 2405: Mejora de 0.000232
# Iteración 2406: Mejora de 0.000232
# Iteración 2407: Mejora de 0.000231
# Iteración 2408: Mejora de 0.000230
# Iteración 2409: Mejora de 0.000230
# Iteración 2410: Mejora de 0.000229
# Iteración 2411: Mejora de 0.000229
# Iteración 2412: Mejora de 0.000228
# Iteración 2413: Mejora de 0.000227
# Iteración 2414: Mejora de 0.000227
# Iteración 2415: Mejora de 0.000226
# Iteración 2416: Mejora de 0.000226
# Iteración 2417: Mejora de 0.000225
# Iteración 2418: Mejora de 0.000224
# Iteración 2419: Mejora de 0.000224
# Iteración 2420: Mejora de 0.000223
# Iteración 2421: Mejora de 0.000223
# Iteración 2422: Mejora de 0.000222
# Iteración 2423: Mejora de 0.000221
# Iteración 2424: Mejora de 0.000221
# Iteración 2425: Mejora de 0.000220
# Iteración 2426: Mejora de 0.000220
# Iteración 2427: Mejora de 0.000219
# Iteración 2428: Mejora de 0.000219
# Iteración 2429: Mejora de 0.000218
# Iteración 2430: Mejora de 0.000217
# Iteración 2431: Mejora de 0.000217
# Iteración 2432: Mejora de 0.000216
# Iteración 2433: Mejora de 0.000216
# Iteración 2434: Mejora de 0.000215
# Iteración 2435: Mejora de 0.000215
# Iteración 2436: Mejora de 0.000214
# Iteración 2437: Mejora de 0.000213
# Iteración 2438: Mejora de 0.000213
# Iteración 2439: Mejora de 0.000212
# Iteración 2440: Mejora de 0.000212
# Iteración 2441: Mejora de 0.000211
# Iteración 2442: Mejora de 0.000211
# Iteración 2443: Mejora de 0.000210
# Iteración 2444: Mejora de 0.000210
# Iteración 2445: Mejora de 0.000209
# Iteración 2446: Mejora de 0.000208
# Iteración 2447: Mejora de 0.000208
# Iteración 2448: Mejora de 0.000207
# Iteración 2449: Mejora de 0.000207
# Iteración 2450: Mejora de 0.000206
# Iteración 2451: Mejora de 0.000206
# Iteración 2452: Mejora de 0.000205
# Iteración 2453: Mejora de 0.000205
# Iteración 2454: Mejora de 0.000204
# Iteración 2455: Mejora de 0.000204
# Iteración 2456: Mejora de 0.000203
# Iteración 2457: Mejora de 0.000203
# Iteración 2458: Mejora de 0.000202
# Iteración 2459: Mejora de 0.000201
# Iteración 2460: Mejora de 0.000201
# Iteración 2461: Mejora de 0.000200
# Iteración 2462: Mejora de 0.000200
# Iteración 2463: Mejora de 0.000199
# Iteración 2464: Mejora de 0.000199
# Iteración 2465: Mejora de 0.000198
# Iteración 2466: Mejora de 0.000198
# Iteración 2467: Mejora de 0.000197
# Iteración 2468: Mejora de 0.000197
# Iteración 2469: Mejora de 0.000196
# Iteración 2470: Mejora de 0.000196
# Iteración 2471: Mejora de 0.000195
# Iteración 2472: Mejora de 0.000195
# Iteración 2473: Mejora de 0.000194
# Iteración 2474: Mejora de 0.000194
# Iteración 2475: Mejora de 0.000193
# Iteración 2476: Mejora de 0.000193
# Iteración 2477: Mejora de 0.000192
# Iteración 2478: Mejora de 0.000192
# Iteración 2479: Mejora de 0.000191
# Iteración 2480: Mejora de 0.000191
# Iteración 2481: Mejora de 0.000190
# Iteración 2482: Mejora de 0.000190
# Iteración 2483: Mejora de 0.000189
# Iteración 2484: Mejora de 0.000189
# Iteración 2485: Mejora de 0.000188
# Iteración 2486: Mejora de 0.000188
# Iteración 2487: Mejora de 0.000187
# Iteración 2488: Mejora de 0.000187
# Iteración 2489: Mejora de 0.000186
# Iteración 2490: Mejora de 0.000186
# Iteración 2491: Mejora de 0.000185
# Iteración 2492: Mejora de 0.000185
# Iteración 2493: Mejora de 0.000184
# Iteración 2494: Mejora de 0.000184
# Iteración 2495: Mejora de 0.000183
# Iteración 2496: Mejora de 0.000183
# Iteración 2497: Mejora de 0.000182
# Iteración 2498: Mejora de 0.000182
# Iteración 2499: Mejora de 0.000181
# Iteración 2500: Mejora de 0.000181
# Iteración 2501: Mejora de 0.000180
# Iteración 2502: Mejora de 0.000180
# Iteración 2503: Mejora de 0.000179
# Iteración 2504: Mejora de 0.000179
# Iteración 2505: Mejora de 0.000179
# Iteración 2506: Mejora de 0.000178
# Iteración 2507: Mejora de 0.000178
# Iteración 2508: Mejora de 0.000177
# Iteración 2509: Mejora de 0.000177
# Iteración 2510: Mejora de 0.000176
# Iteración 2511: Mejora de 0.000176
# Iteración 2512: Mejora de 0.000175
# Iteración 2513: Mejora de 0.000175
# Iteración 2514: Mejora de 0.000174
# Iteración 2515: Mejora de 0.000174
# Iteración 2516: Mejora de 0.000173
# Iteración 2517: Mejora de 0.000173
# Iteración 2518: Mejora de 0.000173
# Iteración 2519: Mejora de 0.000172
# Iteración 2520: Mejora de 0.000172
# Iteración 2521: Mejora de 0.000171
# Iteración 2522: Mejora de 0.000171
# Iteración 2523: Mejora de 0.000170
# Iteración 2524: Mejora de 0.000170
# Iteración 2525: Mejora de 0.000169
# Iteración 2526: Mejora de 0.000169
# Iteración 2527: Mejora de 0.000168
# Iteración 2528: Mejora de 0.000168
# Iteración 2529: Mejora de 0.000168
# Iteración 2530: Mejora de 0.000167
# Iteración 2531: Mejora de 0.000167
# Iteración 2532: Mejora de 0.000166
# Iteración 2533: Mejora de 0.000166
# Iteración 2534: Mejora de 0.000165
# Iteración 2535: Mejora de 0.000165
# Iteración 2536: Mejora de 0.000165
# Iteración 2537: Mejora de 0.000164
# Iteración 2538: Mejora de 0.000164
# Iteración 2539: Mejora de 0.000163
# Iteración 2540: Mejora de 0.000163
# Iteración 2541: Mejora de 0.000162
# Iteración 2542: Mejora de 0.000162
# Iteración 2543: Mejora de 0.000162
# Iteración 2544: Mejora de 0.000161
# Iteración 2545: Mejora de 0.000161
# Iteración 2546: Mejora de 0.000160
# Iteración 2547: Mejora de 0.000160
# Iteración 2548: Mejora de 0.000159
# Iteración 2549: Mejora de 0.000159
# Iteración 2550: Mejora de 0.000159
# Iteración 2551: Mejora de 0.000158
# Iteración 2552: Mejora de 0.000158
# Iteración 2553: Mejora de 0.000157
# Iteración 2554: Mejora de 0.000157
# Iteración 2555: Mejora de 0.000157
# Iteración 2556: Mejora de 0.000156
# Iteración 2557: Mejora de 0.000156
# Iteración 2558: Mejora de 0.000155
# Iteración 2559: Mejora de 0.000155
# Iteración 2560: Mejora de 0.000154
# Iteración 2561: Mejora de 0.000154
# Iteración 2562: Mejora de 0.000154
# Iteración 2563: Mejora de 0.000153
# Iteración 2564: Mejora de 0.000153
# Iteración 2565: Mejora de 0.000152
# Iteración 2566: Mejora de 0.000152
# Iteración 2567: Mejora de 0.000152
# Iteración 2568: Mejora de 0.000151
# Iteración 2569: Mejora de 0.000151
# Iteración 2570: Mejora de 0.000150
# Iteración 2571: Mejora de 0.000150
# Iteración 2572: Mejora de 0.000150
# Iteración 2573: Mejora de 0.000149
# Iteración 2574: Mejora de 0.000149
# Iteración 2575: Mejora de 0.000148
# Iteración 2576: Mejora de 0.000148
# Iteración 2577: Mejora de 0.000148
# Iteración 2578: Mejora de 0.000147
# Iteración 2579: Mejora de 0.000147
# Iteración 2580: Mejora de 0.000147
# Iteración 2581: Mejora de 0.000146
# Iteración 2582: Mejora de 0.000146
# Iteración 2583: Mejora de 0.000145
# Iteración 2584: Mejora de 0.000145
# Iteración 2585: Mejora de 0.000145
# Iteración 2586: Mejora de 0.000144
# Iteración 2587: Mejora de 0.000144
# Iteración 2588: Mejora de 0.000144
# Iteración 2589: Mejora de 0.000143
# Iteración 2590: Mejora de 0.000143
# Iteración 2591: Mejora de 0.000142
# Iteración 2592: Mejora de 0.000142
# Iteración 2593: Mejora de 0.000142
# Iteración 2594: Mejora de 0.000141
# Iteración 2595: Mejora de 0.000141
# Iteración 2596: Mejora de 0.000141
# Iteración 2597: Mejora de 0.000140
# Iteración 2598: Mejora de 0.000140
# Iteración 2599: Mejora de 0.000139
# Iteración 2600: Mejora de 0.000139
# Iteración 2601: Mejora de 0.000139
# Iteración 2602: Mejora de 0.000138
# Iteración 2603: Mejora de 0.000138
# Iteración 2604: Mejora de 0.000138
# Iteración 2605: Mejora de 0.000137
# Iteración 2606: Mejora de 0.000137
# Iteración 2607: Mejora de 0.000137
# Iteración 2608: Mejora de 0.000136
# Iteración 2609: Mejora de 0.000136
# Iteración 2610: Mejora de 0.000135
# Iteración 2611: Mejora de 0.000135
# Iteración 2612: Mejora de 0.000135
# Iteración 2613: Mejora de 0.000134
# Iteración 2614: Mejora de 0.000134
# Iteración 2615: Mejora de 0.000134
# Iteración 2616: Mejora de 0.000133
# Iteración 2617: Mejora de 0.000133
# Iteración 2618: Mejora de 0.000133
# Iteración 2619: Mejora de 0.000132
# Iteración 2620: Mejora de 0.000132
# Iteración 2621: Mejora de 0.000132
# Iteración 2622: Mejora de 0.000131
# Iteración 2623: Mejora de 0.000131
# Iteración 2624: Mejora de 0.000131
# Iteración 2625: Mejora de 0.000130
# Iteración 2626: Mejora de 0.000130
# Iteración 2627: Mejora de 0.000130
# Iteración 2628: Mejora de 0.000129
# Iteración 2629: Mejora de 0.000129
# Iteración 2630: Mejora de 0.000128
# Iteración 2631: Mejora de 0.000128
# Iteración 2632: Mejora de 0.000128
# Iteración 2633: Mejora de 0.000127
# Iteración 2634: Mejora de 0.000127
# Iteración 2635: Mejora de 0.000127
# Iteración 2636: Mejora de 0.000126
# Iteración 2637: Mejora de 0.000126
# Iteración 2638: Mejora de 0.000126
# Iteración 2639: Mejora de 0.000125
# Iteración 2640: Mejora de 0.000125
# Iteración 2641: Mejora de 0.000125
# Iteración 2642: Mejora de 0.000125
# Iteración 2643: Mejora de 0.000124
# Iteración 2644: Mejora de 0.000124
# Iteración 2645: Mejora de 0.000124
# Iteración 2646: Mejora de 0.000123
# Iteración 2647: Mejora de 0.000123
# Iteración 2648: Mejora de 0.000123
# Iteración 2649: Mejora de 0.000122
# Iteración 2650: Mejora de 0.000122
# Iteración 2651: Mejora de 0.000122
# Iteración 2652: Mejora de 0.000121
# Iteración 2653: Mejora de 0.000121
# Iteración 2654: Mejora de 0.000121
# Iteración 2655: Mejora de 0.000120
# Iteración 2656: Mejora de 0.000120
# Iteración 2657: Mejora de 0.000120
# Iteración 2658: Mejora de 0.000119
# Iteración 2659: Mejora de 0.000119
# Iteración 2660: Mejora de 0.000119
# Iteración 2661: Mejora de 0.000118
# Iteración 2662: Mejora de 0.000118
# Iteración 2663: Mejora de 0.000118
# Iteración 2664: Mejora de 0.000118
# Iteración 2665: Mejora de 0.000117
# Iteración 2666: Mejora de 0.000117
# Iteración 2667: Mejora de 0.000117
# Iteración 2668: Mejora de 0.000116
# Iteración 2669: Mejora de 0.000116
# Iteración 2670: Mejora de 0.000116
# Iteración 2671: Mejora de 0.000115
# Iteración 2672: Mejora de 0.000115
# Iteración 2673: Mejora de 0.000115
# Iteración 2674: Mejora de 0.000114
# Iteración 2675: Mejora de 0.000114
# Iteración 2676: Mejora de 0.000114
# Iteración 2677: Mejora de 0.000114
# Iteración 2678: Mejora de 0.000113
# Iteración 2679: Mejora de 0.000113
# Iteración 2680: Mejora de 0.000113
# Iteración 2681: Mejora de 0.000112
# Iteración 2682: Mejora de 0.000112
# Iteración 2683: Mejora de 0.000112
# Iteración 2684: Mejora de 0.000111
# Iteración 2685: Mejora de 0.000111
# Iteración 2686: Mejora de 0.000111
# Iteración 2687: Mejora de 0.000111
# Iteración 2688: Mejora de 0.000110
# Iteración 2689: Mejora de 0.000110
# Iteración 2690: Mejora de 0.000110
# Iteración 2691: Mejora de 0.000109
# Iteración 2692: Mejora de 0.000109
# Iteración 2693: Mejora de 0.000109
# Iteración 2694: Mejora de 0.000109
# Iteración 2695: Mejora de 0.000108
# Iteración 2696: Mejora de 0.000108
# Iteración 2697: Mejora de 0.000108
# Iteración 2698: Mejora de 0.000107
# Iteración 2699: Mejora de 0.000107
# Iteración 2700: Mejora de 0.000107
# Iteración 2701: Mejora de 0.000107
# Iteración 2702: Mejora de 0.000106
# Iteración 2703: Mejora de 0.000106
# Iteración 2704: Mejora de 0.000106
# Iteración 2705: Mejora de 0.000105
# Iteración 2706: Mejora de 0.000105
# Iteración 2707: Mejora de 0.000105
# Iteración 2708: Mejora de 0.000105
# Iteración 2709: Mejora de 0.000104
# Iteración 2710: Mejora de 0.000104
# Iteración 2711: Mejora de 0.000104
# Iteración 2712: Mejora de 0.000104
# Iteración 2713: Mejora de 0.000103
# Iteración 2714: Mejora de 0.000103
# Iteración 2715: Mejora de 0.000103
# Iteración 2716: Mejora de 0.000102
# Iteración 2717: Mejora de 0.000102
# Iteración 2718: Mejora de 0.000102
# Iteración 2719: Mejora de 0.000102
# Iteración 2720: Mejora de 0.000101
# Iteración 2721: Mejora de 0.000101
# Iteración 2722: Mejora de 0.000101
# Iteración 2723: Mejora de 0.000101
# Iteración 2724: Mejora de 0.000100
# Iteración 2725: Mejora de 0.000100
# Iteración 2726: Mejora de 0.000100
# Detenido por convergencia en la iteración 2726
# --- Resultados Finales ---
# Intercepto (w0): 45.6292  (Debería ser ~46.2)
# Pendiente (w1): -0.074465 (Debería ser ~-0.0076

# %% [markdown]
# ### 2.2 Aplicar al dataset de consumo de combustible
#
# Leemos de nuevo los datos y aplicamos la función que acabamos de programar.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
auto_mpg = fetch_ucirepo(id=9) 
  
# data (as pandas dataframes) 
X = auto_mpg.data.features 
y = auto_mpg.data.targets 
  
# convert to numpy
X_np = X['weight'].to_numpy().reshape((X.shape[0], 1))
y_np = y.to_numpy()

print(X_np.shape)
print(y_np.shape)
# Out:
# (398, 1)
# (398, 1)

# %% [markdown]
# Para ayudar al algoritmo, vamos a escalar la variable X, restando la media y dividiendo entre la desviación estándar. Después aplicamos la función anterior y dibujamos.

# %%
X = auto_mpg.data.features
y = auto_mpg.data.targets
X_np = X['weight'].to_numpy().reshape((X.shape[0], 1))
y_np = y.to_numpy()
X_gd = (X_np - X_np.mean()) / X_np.std()
y_gd = y_np
np.random.seed(42)
w0_inicial = np.random.randn(2, 1) 
eta = 0.1                         
iteraciones = 1000                 
tolerancia = 0.0001                
weights_history, loss_history = gradient_descent(X_gd, y_gd, w0_inicial, iteraciones, eta, tol=tolerancia)
w_final = weights_history[-1]
x_max = np.max(X_gd) + 1
x_min = np.min(X_gd) - 1
x_recta = np.linspace(x_min, x_max, 100).reshape(-1, 1)
x_recta_b = np.c_[np.ones((100, 1)), x_recta]
y_recta = x_recta_b @ w_final
plt.figure(figsize=(10, 6))
plt.scatter(X_gd, y_gd, color='blue', alpha=0.5, label='Datos escalados')
plt.plot(x_recta, y_recta, color='red', linewidth=3, label=f'Recta GD (iter: {len(loss_history)})')
plt.title('Regresión Lineal: MPG vs Peso (Datos Estandarizados)', fontsize=14)
plt.xlabel('Peso estandarizado (Z-score)', fontsize=12)
plt.ylabel('Millas por galón (MPG)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

print(f"Pesos finales en escala estandarizada: Intercepto={w_final[0][0]:.4f}, Pendiente={w_final[1][0]:.4f}")
# Out:
# Iteración 1: Mejora de 205.272251
# Iteración 2: Mejora de 131.374241
# Iteración 3: Mejora de 84.079514
# Iteración 4: Mejora de 53.810889
# Iteración 5: Mejora de 34.438969
# Iteración 6: Mejora de 22.040940
# Iteración 7: Mejora de 14.106202
# Iteración 8: Mejora de 9.027969
# Iteración 9: Mejora de 5.777900
# Iteración 10: Mejora de 3.697856
# Iteración 11: Mejora de 2.366628
# Iteración 12: Mejora de 1.514642
# Iteración 13: Mejora de 0.969371
# Iteración 14: Mejora de 0.620397
# Iteración 15: Mejora de 0.397054
# Iteración 16: Mejora de 0.254115
# Iteración 17: Mejora de 0.162633
# Iteración 18: Mejora de 0.104085
# Iteración 19: Mejora de 0.066615
# Iteración 20: Mejora de 0.042633
# Iteración 21: Mejora de 0.027285
# Iteración 22: Mejora de 0.017463
# Iteración 23: Mejora de 0.011176
# Iteración 24: Mejora de 0.007153
# Iteración 25: Mejora de 0.004578
# Iteración 26: Mejora de 0.002930
# Iteración 27: Mejora de 0.001875
# Iteración 28: Mejora de 0.001200
# Iteración 29: Mejora de 0.000768
# Iteración 30: Mejora de 0.000492
# Iteración 31: Mejora de 0.000315
# Iteración 32: Mejora de 0.000201
# Iteración 33: Mejora de 0.000129
# Iteración 34: Mejora de 0.000082
# Detenido por convergencia en la iteración 34
# Pesos finales en escala estandarizada: Intercepto=23.5029, Pendiente=-6.4895
